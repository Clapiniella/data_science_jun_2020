# %% [markdown]
# ## Working on Jsons

# %%
import requests
import json
import pandas as pd

# %%
r = requests.get(url='https://covid19tracking.narrativa.com/feed_en.json')
json_readed = json.loads(r.text)
json_readed
# Out:
# munidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/28&gen_time=14%3A11&client=default_web&region=world',
#     '_id': 'df2c7402c292508dccc86291880d1d49',
#     'id': '2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC'},
#    {'date': '2020-05-28T13:55:13+02:00',
#     'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default',
#      'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#      'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#       'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#       'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#       'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#       'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#       'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#       'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#       'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#       'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#       'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#       'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#       'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#       'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#       'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#       'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#       'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#       'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#      'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C637%2C932&actives_num=2%2C928%2C656&recovered_num=2%2C363%2C902&deaths_num=345%2C374&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default',
#      'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C637%2C932&deaths_num=345%2C374&date=28%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C699%2C933%29%2C%20Brasil%20%28411%2C821%29%2C%20Rusia%20%28379%2C051%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#      'composition_type': 'world',
#      'country_selected': None,
#      'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C637%2C932&actives_num=2%2C928%2C656&recovered_num=2%2C363%2C902&deaths_num=345%2C374&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#      'state_selected': None},
#     'author': 'Narrativa',
#     '_rev': '1-6d68f2ced837d30f1b846b5e6110b62a',
#     'language': 'en_generic',
#     'title': 'Coronavirus outbreak latest: <strong>1,668</strong> new cases reported worldwide',
#     'content': '<p><small>Narrativa | Thursday, May 28, 2020 </small></p><p>There are now <strong>5,637,932</strong> <strong>people infected worldwide</strong>, with <strong>2,363,902</strong></strong> of these having already recovered, according to the data <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">provided by Johns Hopkins University</a>. <b>The US</b> tops the list with <strong>1,699,933</strong> recorded cases, followed by <b> Brazil</b>, <b> Russia</b>, and <b>The United Kingdom</b>, who have confirmed <strong>411,821, 379,051, and 268,619</strong> cases respectively.</p><h4>Coronavirus in the world</h4><p><table width="100%"><thead><tr><th><strong>Active Cases</strong></th><th colspan="2"><strong>Infected</strong></th><th colspan="2"><strong>Deaths</strong></th><th colspan="2"><strong>Recovered</strong></th></tr><tr><th>Total</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th></tr></thead><tbody><tr><td>1. The US: 1,207,983</td><td>1. The US: 1,699,933</td><td>1. Russia: 8,371</td><td>1. The US: 100,442</td><td>1. Russia: 174</td><td>1. The US: 391,508</strong></td><td>1. Russia: 8,785</strong></td></tr><tr><td>2. The United Kingdom: 229,911</td><td>2. Brazil: 411,821</td><td>2. Iran: 2,258</td><td>2. The United Kingdom: 37,542</td><td>2. The US: 166</td><td>2. Brazil: 166,647</strong></td><td>2. Italy: 2,443</strong></td></tr><tr><td>3. Russia: 223,916</td><td>3. Russia: 379,051</td><td>3. Pakistan: 2,076</td><td>3. Italy: 33,072</td><td>3. Italy: 117</td><td>3. Germany: 163,010</strong></td><td>3. Mexico: 2,126</strong></td></tr></tbody></table></p><p>During the last 24 hours, there has been a <strong>0.03</strong>% increase with <strong>1,668</strong> new cases. <strong> Russia</strong> has the most new cases so far with <strong>8,371</strong>, followed by <b> Iran</b> with <strong>2,258</strong>. <strong> Pakistan</strong> and <strong> Bangladesh</strong> are not far behind, with <strong>2,076</strong> and <strong>2,029</strong> new patients respectively.</p><p> </p><p>Since the coronavirus outbreak started, a total of<strong> 345,374 people</strong> have died worldwide. <strong>The US</strong> has registered the most victims so far with <strong>100,442</strong> deceased, followed by <strong>The United Kingdom, Italy, and Spain</strong> with <strong>37,542, 33,072, and 27,940</strong> deaths respectively.</p><p>The first signs of the virus appeared in <strong>China</strong>, in the city of <strong>Wuhan</strong>, on <strong>31 December 2019</strong>. Since that date, the number of infections have multiplied across the continent and the globe. As of the latest reports, cases in China have grown to <strong>2</strong> new cases since Wednesday. Overall, <strong>98</strong> people are infected with the virus.</p><hr><p><strong>Note</strong>: This article has been <strong><u>generated automatically by <a href="https://www.narrativa.com" target="_blank">Narrativa</a></u></strong> from the data by <a href="https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/situacionActual.htm" target="_blank">Ministerio de Sanidad</a>, <a href="https://github.com/pcm-dpc/COVID-19" target="_blank">Dipartimento della Protezione Civile de Italia</a>, <a href="https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Situationsberichte/Gesamt.html" target="_blank">Robert Koch Institute</a> and <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">Johns Hopkins University</a>.</p>',
#     'picurl_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C637%2C932&actives_num=2%2C928%2C656&recovered_num=2%2C363%2C902&deaths_num=345%2C374&date=28%20de%20mayo%20del%202020&top_paises1=EE.UU.%3A%201%2C699%2C933&top_paises2=Brasil%3A%20411%2C821&top_paises3=Rusia%3A%20379%2C051&client=default&region=world',
#     'picurl': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&top_comunidades=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&client=default&region=spain',
#     'metatitle': '',
#     'subtitle': '',
#     'picurl_banner_web': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C637%2C932&actives_num=2%2C928%2C656&recovered_num=2%2C363%2C902&deaths_num=345%2C374&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C699%2C933&top_paises2_num=411%2C821&top_paises3_num=379%2C051&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/28&gen_time=13%3A35&client=default_web&region=world',
#     '_id': 'df2c7402c292508dccc8629188014dde',
#     'id': '2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC'},
#    {'date': '2020-05-28T12:26:05+02:00',
#     'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default',
#      'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#      'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#       'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#       'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#       'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#       'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#       'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#       'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#       'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#       'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#       'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#       'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#       'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#       'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#       'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#       'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#       'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#       'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#      'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C658%2C868&actives_num=2%2C953%2C149&recovered_num=2%2C359%2C521&deaths_num=346%2C198&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default',
#      'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C658%2C868&deaths_num=346%2C198&date=28%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C699%2C933%29%2C%20Brasil%20%28411%2C821%29%2C%20Rusia%20%28379%2C051%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#      'composition_type': 'world',
#      'country_selected': None,
#      'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C658%2C868&actives_num=2%2C953%2C149&recovered_num=2%2C359%2C521&deaths_num=346%2C198&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#      'state_selected': None},
#     'author': 'Narrativa',
#     '_rev': '1-27b05d532847f3930e2e4e0acf24eb37',
#     'language': 'en_generic',
#     'title': 'Coronavirus outbreak latest: <strong>22,604</strong> new cases reported worldwide',
#     'content': '<p><small>Narrativa | Thursday, May 28, 2020 </small></p><p>The number of COVID-19 cases worldwide is now at <strong>5,658,868</strong>, of which <strong>2,359,521</strong></strong> have already recovered, according to the data <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">provided by Johns Hopkins University</a>. <b>The US</b> has the most cases with <strong>1,699,933</strong>, followed by <b> Brazil</b>, <b> Russia</b>, and <b>The United Kingdom</b>, who have confirmed <strong>411,821, 379,051, and 268,619</strong> cases respectively.</p><h4>COVID-19 Status Worldwide</h4><p><table width="100%"><thead><tr><th><strong>Currently Infected</strong></th><th colspan="2"><strong>Infected</strong></th><th colspan="2"><strong>Deaths</strong></th><th colspan="2"><strong>Recovered</strong></th></tr><tr><th>Total</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th></tr></thead><tbody><tr><td>1. The US: 1,207,983</td><td>1. The US: 1,699,933</td><td>1. Russia: 8,371</td><td>1. The US: 100,442</td><td>1. Russia: 174</td><td>1. The US: 391,508</strong></td><td>1. Russia: 8,785</strong></td></tr><tr><td>2. The United Kingdom: 229,911</td><td>2. Brazil: 411,821</td><td>2. Pakistan: 2,076</td><td>2. The United Kingdom: 37,542</td><td>2. The US: 166</td><td>2. Brazil: 166,647</strong></td><td>2. Italy: 2,443</strong></td></tr><tr><td>3. Russia: 223,916</td><td>3. Russia: 379,051</td><td>3. Bangladesh: 2,029</td><td>3. Italy: 33,072</td><td>3. Italy: 117</td><td>3. Germany: 163,010</strong></td><td>3. Mexico: 2,126</strong></td></tr></tbody></table></p><p>Moreover, <strong>22,604</strong> new cases have been confirmed in the last 24 hours, which means an increase of <strong>0.4</strong>% from the previous day. <strong> Russia</strong> is the country with the most new cases, having now confirmed <strong>8,371</strong>, followed by <b> Pakistan</b> with <strong>2,076</strong>. <strong> Bangladesh</strong> and <strong>The United Kingdom</strong> are not far behind, with <strong>1,379</strong> and <strong>1,379</strong> new patients respectively.</p><p> </p><p>Since the beginning, <strong>the number of COVID-19 related deaths worldwide</strong> is <strong>346,198 people</strong>, including the <strong>862</strong> new deaths over last 24 hours. <strong>The US</strong> has the most victims so far with <strong>100,442</strong> deaths, followed by <strong>The United Kingdom, Italy, and Spain</strong> with <strong>37,542, 33,072, and 27,940</strong> deaths respectively.</p><p>The first evidences about this new strain of the virus appeared in <strong>China</strong>, in the city of <strong>Wuhan</strong>, on <strong>31 December 2019</strong>. Since that date, the number of infections have multiplied across the continent and the globe. As of the latest reports, cases in China have increased to <strong>2</strong> new cases since yesterday. Overall, <strong>98</strong> people are infected with coronavirus.</p><hr><p><strong>Note</strong>: This article has been <strong><u>generated automatically by <a href="https://www.narrativa.com" target="_blank">Narrativa</a></u></strong> from the data by <a href="https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/situacionActual.htm" target="_blank">Ministerio de Sanidad</a>, <a href="https://github.com/pcm-dpc/COVID-19" target="_blank">Dipartimento della Protezione Civile de Italia</a>, <a href="https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Situationsberichte/Gesamt.html" target="_blank">Robert Koch Institute</a> and <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">Johns Hopkins University</a>.</p>',
#     'picurl_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C658%2C868&actives_num=2%2C953%2C149&recovered_num=2%2C359%2C521&deaths_num=346%2C198&date=28%20de%20mayo%20del%202020&top_paises1=EE.UU.%3A%201%2C699%2C933&top_paises2=Brasil%3A%20411%2C821&top_paises3=Rusia%3A%20379%2C051&client=default&region=world',
#     'picurl': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&top_comunidades=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&client=default&region=spain',
#     'metatitle': '',
#     'subtitle': '',
#     'picurl_banner_web': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C658%2C868&actives_num=2%2C953%2C149&recovered_num=2%2C359%2C521&deaths_num=346%2C198&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C699%2C933&top_paises2_num=411%2C821&top_paises3_num=379%2C051&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/28&gen_time=12%3A16&client=default_web&region=world',
#     '_id': 'a9a97d8366303af830c81363bfe2ef34',
#     'id': '2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC'}]}}

# %%
print(json_readed)
# Out:
# d_num=2%2C364%2C087&deaths_num=346%2C282&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C699%2C933&top_paises2_num=411%2C821&top_paises3_num=379%2C051&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/28&gen_time=14%3A11&client=default_web&region=world', '_id': 'df2c7402c292508dccc86291880d1d49', 'id': '2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC'}, {'date': '2020-05-28T13:55:13+02:00', 'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default', 'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true', 'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png', 'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png', 'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png', 'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png', 'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png', 'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png', 'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png', 'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png', 'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png', 'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png', 'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png', 'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png', 'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png', 'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png', 'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png', 'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png', 'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'}, 'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C637%2C932&actives_num=2%2C928%2C656&recovered_num=2%2C363%2C902&deaths_num=345%2C374&dat ...

# %% [markdown]
# Save json in a local file called "data.json"

# %%
with open('data.json', 'w+') as outfile:
    json.dump(json_readed, outfile)

# %%
with open('data.json') as f:
    line = f.readline()
    if line:
        print(line)
        line = f.readline()
print(line)
# Out:
# %2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C699%2C933&top_paises2_num=411%2C821&top_paises3_num=379%2C051&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/28&gen_time=14%3A11&client=default_web&region=world", "_id": "df2c7402c292508dccc86291880d1d49", "id": "2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC"}, {"date": "2020-05-28T13:55:13+02:00", "metadata": {"picurl_square_spain": "https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default", "picurl_square_spain_extended": "https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true", "graphs": {"graph_picurl_china": "https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png", "graph_picurl_us": "https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png", "graph_picurl_deaths_evolution": "https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png", "graph_picurl_world": "https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png", "graph_picurl_china_confirmed": "https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png", "graph_picurl_us_confirmed": "https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png", "graph_picurl_spain_deaths": "https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png", "graph_picurl_us_recovered": "https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png", "graph_picurl_deaths_log_evolution": "https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png", "graph_picurl_italy": "https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png", "graph_picurl_italy_recovered": "https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png", "graph_picurl_us_deaths": "https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png", "graph_picurl_italy_deaths": "https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png", "graph_picurl_china_deaths": "https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png", "graph_picurl_italy_confirmed": "https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png", "graph_picurl_spain_confirmed": "https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png", "graph_picurl_china_recovered": "https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png"}, "picurl_square_world": "https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C637%2C932&actives_num=2%2C928%2C656&recovered_num=2%2C363%2C902&deaths_num=345%2C374&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&cl ...

# %% [markdown]
# Save with indent

# %%
with open('data_indented.json', 'w+') as outfile:
    json.dump(json_readed, outfile, indent=4)

# %% [markdown]
# Read local json

# %%
with open('data_indented.json', 'r+') as outfile:
    json_readed = json.load(outfile)
json_readed
# Out:
# munidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/28&gen_time=14%3A11&client=default_web&region=world',
#     '_id': 'df2c7402c292508dccc86291880d1d49',
#     'id': '2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC'},
#    {'date': '2020-05-28T13:55:13+02:00',
#     'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default',
#      'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#      'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#       'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#       'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#       'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#       'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#       'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#       'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#       'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#       'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#       'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#       'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#       'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#       'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#       'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#       'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#       'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#       'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#      'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C637%2C932&actives_num=2%2C928%2C656&recovered_num=2%2C363%2C902&deaths_num=345%2C374&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default',
#      'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C637%2C932&deaths_num=345%2C374&date=28%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C699%2C933%29%2C%20Brasil%20%28411%2C821%29%2C%20Rusia%20%28379%2C051%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#      'composition_type': 'world',
#      'country_selected': None,
#      'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C637%2C932&actives_num=2%2C928%2C656&recovered_num=2%2C363%2C902&deaths_num=345%2C374&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#      'state_selected': None},
#     'author': 'Narrativa',
#     '_rev': '1-6d68f2ced837d30f1b846b5e6110b62a',
#     'language': 'en_generic',
#     'title': 'Coronavirus outbreak latest: <strong>1,668</strong> new cases reported worldwide',
#     'content': '<p><small>Narrativa | Thursday, May 28, 2020 </small></p><p>There are now <strong>5,637,932</strong> <strong>people infected worldwide</strong>, with <strong>2,363,902</strong></strong> of these having already recovered, according to the data <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">provided by Johns Hopkins University</a>. <b>The US</b> tops the list with <strong>1,699,933</strong> recorded cases, followed by <b> Brazil</b>, <b> Russia</b>, and <b>The United Kingdom</b>, who have confirmed <strong>411,821, 379,051, and 268,619</strong> cases respectively.</p><h4>Coronavirus in the world</h4><p><table width="100%"><thead><tr><th><strong>Active Cases</strong></th><th colspan="2"><strong>Infected</strong></th><th colspan="2"><strong>Deaths</strong></th><th colspan="2"><strong>Recovered</strong></th></tr><tr><th>Total</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th></tr></thead><tbody><tr><td>1. The US: 1,207,983</td><td>1. The US: 1,699,933</td><td>1. Russia: 8,371</td><td>1. The US: 100,442</td><td>1. Russia: 174</td><td>1. The US: 391,508</strong></td><td>1. Russia: 8,785</strong></td></tr><tr><td>2. The United Kingdom: 229,911</td><td>2. Brazil: 411,821</td><td>2. Iran: 2,258</td><td>2. The United Kingdom: 37,542</td><td>2. The US: 166</td><td>2. Brazil: 166,647</strong></td><td>2. Italy: 2,443</strong></td></tr><tr><td>3. Russia: 223,916</td><td>3. Russia: 379,051</td><td>3. Pakistan: 2,076</td><td>3. Italy: 33,072</td><td>3. Italy: 117</td><td>3. Germany: 163,010</strong></td><td>3. Mexico: 2,126</strong></td></tr></tbody></table></p><p>During the last 24 hours, there has been a <strong>0.03</strong>% increase with <strong>1,668</strong> new cases. <strong> Russia</strong> has the most new cases so far with <strong>8,371</strong>, followed by <b> Iran</b> with <strong>2,258</strong>. <strong> Pakistan</strong> and <strong> Bangladesh</strong> are not far behind, with <strong>2,076</strong> and <strong>2,029</strong> new patients respectively.</p><p> </p><p>Since the coronavirus outbreak started, a total of<strong> 345,374 people</strong> have died worldwide. <strong>The US</strong> has registered the most victims so far with <strong>100,442</strong> deceased, followed by <strong>The United Kingdom, Italy, and Spain</strong> with <strong>37,542, 33,072, and 27,940</strong> deaths respectively.</p><p>The first signs of the virus appeared in <strong>China</strong>, in the city of <strong>Wuhan</strong>, on <strong>31 December 2019</strong>. Since that date, the number of infections have multiplied across the continent and the globe. As of the latest reports, cases in China have grown to <strong>2</strong> new cases since Wednesday. Overall, <strong>98</strong> people are infected with the virus.</p><hr><p><strong>Note</strong>: This article has been <strong><u>generated automatically by <a href="https://www.narrativa.com" target="_blank">Narrativa</a></u></strong> from the data by <a href="https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/situacionActual.htm" target="_blank">Ministerio de Sanidad</a>, <a href="https://github.com/pcm-dpc/COVID-19" target="_blank">Dipartimento della Protezione Civile de Italia</a>, <a href="https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Situationsberichte/Gesamt.html" target="_blank">Robert Koch Institute</a> and <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">Johns Hopkins University</a>.</p>',
#     'picurl_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C637%2C932&actives_num=2%2C928%2C656&recovered_num=2%2C363%2C902&deaths_num=345%2C374&date=28%20de%20mayo%20del%202020&top_paises1=EE.UU.%3A%201%2C699%2C933&top_paises2=Brasil%3A%20411%2C821&top_paises3=Rusia%3A%20379%2C051&client=default&region=world',
#     'picurl': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&top_comunidades=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&client=default&region=spain',
#     'metatitle': '',
#     'subtitle': '',
#     'picurl_banner_web': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C637%2C932&actives_num=2%2C928%2C656&recovered_num=2%2C363%2C902&deaths_num=345%2C374&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C699%2C933&top_paises2_num=411%2C821&top_paises3_num=379%2C051&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/28&gen_time=13%3A35&client=default_web&region=world',
#     '_id': 'df2c7402c292508dccc8629188014dde',
#     'id': '2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC'},
#    {'date': '2020-05-28T12:26:05+02:00',
#     'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default',
#      'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#      'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#       'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#       'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#       'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#       'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#       'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#       'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#       'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#       'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#       'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#       'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#       'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#       'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#       'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#       'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#       'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#       'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#      'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C658%2C868&actives_num=2%2C953%2C149&recovered_num=2%2C359%2C521&deaths_num=346%2C198&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default',
#      'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C658%2C868&deaths_num=346%2C198&date=28%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C699%2C933%29%2C%20Brasil%20%28411%2C821%29%2C%20Rusia%20%28379%2C051%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#      'composition_type': 'world',
#      'country_selected': None,
#      'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C658%2C868&actives_num=2%2C953%2C149&recovered_num=2%2C359%2C521&deaths_num=346%2C198&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#      'state_selected': None},
#     'author': 'Narrativa',
#     '_rev': '1-27b05d532847f3930e2e4e0acf24eb37',
#     'language': 'en_generic',
#     'title': 'Coronavirus outbreak latest: <strong>22,604</strong> new cases reported worldwide',
#     'content': '<p><small>Narrativa | Thursday, May 28, 2020 </small></p><p>The number of COVID-19 cases worldwide is now at <strong>5,658,868</strong>, of which <strong>2,359,521</strong></strong> have already recovered, according to the data <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">provided by Johns Hopkins University</a>. <b>The US</b> has the most cases with <strong>1,699,933</strong>, followed by <b> Brazil</b>, <b> Russia</b>, and <b>The United Kingdom</b>, who have confirmed <strong>411,821, 379,051, and 268,619</strong> cases respectively.</p><h4>COVID-19 Status Worldwide</h4><p><table width="100%"><thead><tr><th><strong>Currently Infected</strong></th><th colspan="2"><strong>Infected</strong></th><th colspan="2"><strong>Deaths</strong></th><th colspan="2"><strong>Recovered</strong></th></tr><tr><th>Total</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th></tr></thead><tbody><tr><td>1. The US: 1,207,983</td><td>1. The US: 1,699,933</td><td>1. Russia: 8,371</td><td>1. The US: 100,442</td><td>1. Russia: 174</td><td>1. The US: 391,508</strong></td><td>1. Russia: 8,785</strong></td></tr><tr><td>2. The United Kingdom: 229,911</td><td>2. Brazil: 411,821</td><td>2. Pakistan: 2,076</td><td>2. The United Kingdom: 37,542</td><td>2. The US: 166</td><td>2. Brazil: 166,647</strong></td><td>2. Italy: 2,443</strong></td></tr><tr><td>3. Russia: 223,916</td><td>3. Russia: 379,051</td><td>3. Bangladesh: 2,029</td><td>3. Italy: 33,072</td><td>3. Italy: 117</td><td>3. Germany: 163,010</strong></td><td>3. Mexico: 2,126</strong></td></tr></tbody></table></p><p>Moreover, <strong>22,604</strong> new cases have been confirmed in the last 24 hours, which means an increase of <strong>0.4</strong>% from the previous day. <strong> Russia</strong> is the country with the most new cases, having now confirmed <strong>8,371</strong>, followed by <b> Pakistan</b> with <strong>2,076</strong>. <strong> Bangladesh</strong> and <strong>The United Kingdom</strong> are not far behind, with <strong>1,379</strong> and <strong>1,379</strong> new patients respectively.</p><p> </p><p>Since the beginning, <strong>the number of COVID-19 related deaths worldwide</strong> is <strong>346,198 people</strong>, including the <strong>862</strong> new deaths over last 24 hours. <strong>The US</strong> has the most victims so far with <strong>100,442</strong> deaths, followed by <strong>The United Kingdom, Italy, and Spain</strong> with <strong>37,542, 33,072, and 27,940</strong> deaths respectively.</p><p>The first evidences about this new strain of the virus appeared in <strong>China</strong>, in the city of <strong>Wuhan</strong>, on <strong>31 December 2019</strong>. Since that date, the number of infections have multiplied across the continent and the globe. As of the latest reports, cases in China have increased to <strong>2</strong> new cases since yesterday. Overall, <strong>98</strong> people are infected with coronavirus.</p><hr><p><strong>Note</strong>: This article has been <strong><u>generated automatically by <a href="https://www.narrativa.com" target="_blank">Narrativa</a></u></strong> from the data by <a href="https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/situacionActual.htm" target="_blank">Ministerio de Sanidad</a>, <a href="https://github.com/pcm-dpc/COVID-19" target="_blank">Dipartimento della Protezione Civile de Italia</a>, <a href="https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Situationsberichte/Gesamt.html" target="_blank">Robert Koch Institute</a> and <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">Johns Hopkins University</a>.</p>',
#     'picurl_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C658%2C868&actives_num=2%2C953%2C149&recovered_num=2%2C359%2C521&deaths_num=346%2C198&date=28%20de%20mayo%20del%202020&top_paises1=EE.UU.%3A%201%2C699%2C933&top_paises2=Brasil%3A%20411%2C821&top_paises3=Rusia%3A%20379%2C051&client=default&region=world',
#     'picurl': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&top_comunidades=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&client=default&region=spain',
#     'metatitle': '',
#     'subtitle': '',
#     'picurl_banner_web': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C658%2C868&actives_num=2%2C953%2C149&recovered_num=2%2C359%2C521&deaths_num=346%2C198&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C699%2C933&top_paises2_num=411%2C821&top_paises3_num=379%2C051&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/28&gen_time=12%3A16&client=default_web&region=world',
#     '_id': 'a9a97d8366303af830c81363bfe2ef34',
#     'id': '2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC'}]}}

# %%
df_json = pd.read_json("data_indented.json")
df_json
# Out:
#                                                    data
# post  [{'date': '2020-07-13T16:03:32+02:00', 'metada...

# %%
df_json.data[0][0]['date']
# Out:
# '2020-07-13T16:03:32+02:00'

# %%
df_json.data[0][1]['date']
# Out:
# '2020-07-13T15:10:44+02:00'

# %%
diccionario_json = {}
lista_json=[]
for json in df_json.data[0]:
    lista_json.append(json)
# Out:
# 1000

# %%
'''    
if type(value) == dict: 
    for key_val, value_val in value: 
        if key not in diccionario_json.keys()
            diccionario_json[key_val] = value_val
        else: 
            diccionario_json 
'''

# %%
for cada_json in lista_json:
    for key, value in cada_json.items(): 
        if key not in diccionario_json.keys():
            diccionario_json[key] = [value]
        else: 
            diccionario_json[key].append(value) 
        if type(value)==dict: 
            for key_val, value_val in value.items():
                print(value)
                break
                if key_val not in diccionario_json.keys():
                    diccionario_json[key_val] = [value_val]
                else:
                    diccionario_json[key_val].append(value)
# Out:
# c_COVID_EN_GENERIC_us.png', 'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png', 'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png', 'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png', 'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png', 'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png', 'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png', 'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png', 'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png', 'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png', 'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png', 'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png', 'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png', 'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png', 'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png', 'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'}, 'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C657%2C702&actives_num=2%2C940%2C827&recovered_num=2%2C371%2C019&deaths_num=345%2C856&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default', 'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C657%2C702&deaths_num=345%2C856&date=28%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C700%2C350%29%2C%20Brasil%20%28411%2C821%29%2C%20Rusia%20%28379%2C051%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default', 'composition_type': 'world', 'country_selected': None, 'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C657%2C702&actives_num=2%2C940%2C827&recovered_num=2%2C371%2C019&deaths_num=345%2C856&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default&extended=true', 'state_selected': None}
# {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default', 'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true', 'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png', 'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png', 'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png', 'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png', 'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png', 'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png', 'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png', 'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png', 'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png', 'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png', 'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png', 'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png', 'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png', 'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png', 'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png', 'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png', 'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'}, 'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C656%2C878&actives_num=2%2C946%2C468&recovered_num=2%2C364%2C572&deaths_num=345%2C838&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default', 'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C656%2C878&deaths_num=345%2C838&date=28%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C699%2C933%29%2C%20Brasil%20%28411%2C821%29%2C%20Rusia%20%28379%2C051%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default', 'composition_type': 'world', 'country_selected': None, 'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C656%2C878&actives_num=2%2C946%2C468&recovered_ ...
# {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default', 'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true', 'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png', 'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png', 'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png', 'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png', 'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png', 'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png', 'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png', 'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png', 'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png', 'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png', 'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png', 'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png', 'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png', 'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png', 'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png', 'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png', 'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'}, 'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C664%2C143&actives_num=2%2C953%2C774&recovered_num=2%2C364%2C087&deaths_num=346%2C282&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default', 'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C664%2C143&deaths_num=346%2C282&date=28%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C699%2C933%29%2C%20Brasil%20%28411%2C821%29%2C%20Rusia%20%28379%2C051%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default', 'composition_type': 'world', 'country_selected': None, 'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C664%2C143&actives_num=2%2C953%2C774&recovered_ ...
# {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default', 'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true', 'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png', 'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png', 'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png', 'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png', 'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png', 'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png', 'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png', 'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png', 'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png', 'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png', 'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png', 'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png', 'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png', 'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png', 'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png', 'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png', 'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'}, 'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C637%2C932&actives_num=2%2C928%2C656&recovered_num=2%2C363%2C902&deaths_num=345%2C374&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default', 'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C637%2C932&deaths_num=345%2C374&date=28%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C699%2C933%29%2C%20Brasil%20%28411%2C821%29%2C%20Rusia%20%28379%2C051%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default', 'composition_type': 'world', 'country_selected': None, 'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C637%2C932&actives_num=2%2C928%2C656&recovered_ ...
# {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default', 'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true', 'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png', 'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png', 'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png', 'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png', 'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png', 'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png', 'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png', 'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png', 'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png', 'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png', 'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png', 'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png', 'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png', 'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png', 'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png', 'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png', 'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'}, 'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C658%2C868&actives_num=2%2C953%2C149&recovered_num=2%2C359%2C521&deaths_num=346%2C198&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default', 'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C658%2C868&deaths_num=346%2C198&date=28%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C699%2C933%29%2C%20Brasil%20%28411%2C821%29%2C%20Rusia%20%28379%2C051%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default', 'composition_type': 'world', 'country_selected': None, 'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C658%2C868&actives_num=2%2C953%2C149&recovered_ ...

# %%
diccionario_json
# Out:
# _GENERIC_china_confirmed.png',
#     'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#     'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#     'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#     'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#     'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#     'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#     'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#     'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#     'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#     'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#     'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#     'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-16_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#    'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C657%2C702&actives_num=2%2C940%2C827&recovered_num=2%2C371%2C019&deaths_num=345%2C856&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default',
#    'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C657%2C702&deaths_num=345%2C856&date=28%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C700%2C350%29%2C%20Brasil%20%28411%2C821%29%2C%20Rusia%20%28379%2C051%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#    'composition_type': 'world',
#    'country_selected': None,
#    'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C657%2C702&actives_num=2%2C940%2C827&recovered_num=2%2C371%2C019&deaths_num=345%2C856&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#    'state_selected': None},
#   {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default',
#    'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#    'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#     'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#     'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#     'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#     'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#     'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#     'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#     'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#     'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#     'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#     'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#     'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#     'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#     'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#     'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#     'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#     'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-15_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#    'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C656%2C878&actives_num=2%2C946%2C468&recovered_num=2%2C364%2C572&deaths_num=345%2C838&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default',
#    'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C656%2C878&deaths_num=345%2C838&date=28%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C699%2C933%29%2C%20Brasil%20%28411%2C821%29%2C%20Rusia%20%28379%2C051%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#    'composition_type': 'world',
#    'country_selected': None,
#    'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C656%2C878&actives_num=2%2C946%2C468&recovered_num=2%2C364%2C572&deaths_num=345%2C838&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#    'state_selected': None},
#   {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default',
#    'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#    'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#     'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#     'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#     'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#     'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#     'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#     'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#     'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#     'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#     'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#     'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#     'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#     'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#     'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#     'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#     'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#     'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-14_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#    'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C664%2C143&actives_num=2%2C953%2C774&recovered_num=2%2C364%2C087&deaths_num=346%2C282&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default',
#    'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C664%2C143&deaths_num=346%2C282&date=28%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C699%2C933%29%2C%20Brasil%20%28411%2C821%29%2C%20Rusia%20%28379%2C051%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#    'composition_type': 'world',
#    'country_selected': None,
#    'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C664%2C143&actives_num=2%2C953%2C774&recovered_num=2%2C364%2C087&deaths_num=346%2C282&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#    'state_selected': None},
#   {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default',
#    'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#    'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#     'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#     'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#     'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#     'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#     'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#     'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#     'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#     'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#     'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#     'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#     'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#     'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#     'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#     'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#     'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#     'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-13_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#    'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C637%2C932&actives_num=2%2C928%2C656&recovered_num=2%2C363%2C902&deaths_num=345%2C374&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default',
#    'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C637%2C932&deaths_num=345%2C374&date=28%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C699%2C933%29%2C%20Brasil%20%28411%2C821%29%2C%20Rusia%20%28379%2C051%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#    'composition_type': 'world',
#    'country_selected': None,
#    'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C637%2C932&actives_num=2%2C928%2C656&recovered_num=2%2C363%2C902&deaths_num=345%2C374&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#    'state_selected': None},
#   {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default',
#    'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#    'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#     'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#     'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#     'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#     'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#     'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#     'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#     'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#     'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#     'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#     'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#     'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#     'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#     'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#     'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#     'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#     'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#    'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C658%2C868&actives_num=2%2C953%2C149&recovered_num=2%2C359%2C521&deaths_num=346%2C198&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default',
#    'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C658%2C868&deaths_num=346%2C198&date=28%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C699%2C933%29%2C%20Brasil%20%28411%2C821%29%2C%20Rusia%20%28379%2C051%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#    'composition_type': 'world',
#    'country_selected': None,
#    'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C658%2C868&actives_num=2%2C953%2C149&recovered_num=2%2C359%2C521&deaths_num=346%2C198&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#    'state_selected': None},
#   ...]}

# %%
data = pd.DataFrame(diccionario_json)
data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-bfadc826f672> in <module>
# ----> 1 data = pd.DataFrame(diccionario_json)
#       2 data.head()
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      62     # figure out the index, if necessary
#      63     if index is None:
# ---> 64         index = extract_index(arrays)
#      65     else:
#      66         index = ensure_index(index)
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     363             lengths = list(set(raw_lengths))
#     364             if len(lengths) > 1:
# --> 365                 raise ValueError("arrays must all be same length")
#     366
#     367             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
for dicti in diccionario["metadata"]:
    print(dicti.keys())
    break
# Out:
# dict_keys(['picurl_square_spain', 'picurl_square_spain_extended', 'graphs', 'picurl_square_world', 'picurl_16_9_spain', 'composition_type', 'country_selected', 'picurl_square_world_extended', 'state_selected'])

# %%
df_json.data[0][1]['date']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-44-81144008b628> in <module>
# ----> 1 df_json.data[1][1]['date']
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4409
#    4410             try:
# -> 4411                 return libindex.get_value_at(s, key)
#    4412             except IndexError:
#    4413                 raise
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.validate_indexer()
#
# IndexError: index out of bounds

# %%
df = df_json.explode('data').apply(lambda e: e.data, axis = 1, result_type = 'expand')
df
# Out:
#                            date  \
# post  2020-07-13T16:03:32+02:00
# post  2020-07-13T15:10:44+02:00
# post  2020-07-13T14:08:52+02:00
# post  2020-07-13T13:01:51+02:00
# post  2020-07-13T12:02:36+02:00
# ...                         ...
# post  2020-05-28T16:18:46+02:00
# post  2020-05-28T15:16:02+02:00
# post  2020-05-28T14:16:02+02:00
# post  2020-05-28T13:55:13+02:00
# post  2020-05-28T12:26:05+02:00
#
#                                                metadata     author  \
# post  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# post  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# post  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# post  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# post  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# ...                                                 ...        ...
# post  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# post  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# post  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# post  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# post  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
#
#                                     _rev    language  \
# post  1-dcca4c2578b878b87e8fe6035d232424  en_generic
# post  1-f66ee74f8d7f9610fd5a19e22cddf9a6  en_generic
# post  1-90a629485558de63cd7b91c1cb96aca8  en_generic
# post  1-fff13ddf97a006f1c69d7e23db4fff70  en_generic
# post  1-7ca8cdc55e3c11a3b7bb6fb2b3c66dec  en_generic
# ...                                  ...         ...
# post  1-592050036e0ac1511def2c7617f96643  en_generic
# post  1-0b955ec4c7c31fa9d52c067a60ad27eb  en_generic
# post  1-00cfd5d408492b6c6bf149569a0c18e3  en_generic
# post  1-6d68f2ced837d30f1b846b5e6110b62a  en_generic
# post  1-27b05d532847f3930e2e4e0acf24eb37  en_generic
#
#                                                   title  \
# post  Coronavirus outbreak latest: <strong>1,282</st...
# post  Coronavirus outbreak latest: <strong>40,869</s...
# post  Coronavirus outbreak latest: <strong>12,871,02...
# post  Coronavirus outbreak latest: <strong>557,948</...
# post  Coronavirus outbreak latest: <strong>714</stro...
# ...                                                 ...
# post  Coronavirus outbreak latest: <strong>345,856</...
# post  Coronavirus outbreak latest: <strong>502</stro...
# post  Coronavirus outbreak latest: <strong>946</stro...
# post  Coronavirus outbreak latest: <strong>1,668</st...
# post  Coronavirus outbreak latest: <strong>22,604</s...
#
#                                                 content  \
# post  <p><small>Narrativa | Monday, July 13, 2020 </...
# post  <p><small>Narrativa | Monday, July 13, 2020 </...
# post  <p><small>Narrativa | Monday, July 13, 2020 </...
# post  <p><small>Narrativa | Monday, July 13, 2020 </...
# post  <p><small>Narrativa | Monday, July 13, 2020 </...
# ...                                                 ...
# post  <p><small>Narrativa | Thursday, May 28, 2020 <...
# post  <p><small>Narrativa | Thursday, May 28, 2020 <...
# post  <p><small>Narrativa | Thursday, May 28, 2020 <...
# post  <p><small>Narrativa | Thursday, May 28, 2020 <...
# post  <p><small>Narrativa | Thursday, May 28, 2020 <...
#
#                                            picurl_world  \
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ...                                                 ...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
#
#                                                  picurl metatitle subtitle  \
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ...                                                 ...       ...      ...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
#
#                                       picurl_banner_web  \
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ...                                                 ...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# post  https://4i2g925ohj.execute-api.eu-west-3.amazo...
#
#                                    _id  \
# post  95a8dfdaec69cd5225aad0c2ef6d4c87
# post  95a8dfdaec69cd5225aad0c2ef49738f
# post  95a8dfdaec69cd5225aad0c2ef42ef60
# post  95a8dfdaec69cd5225aad0c2ef383fef
# post  95a8dfdaec69cd5225aad0c2ef299573
# ...                                ...
# post  df2c7402c292508dccc862918879b996
# post  df2c7402c292508dccc86291881f3432
# post  df2c7402c292508dccc86291880d1d49
# post  df2c7402c292508dccc8629188014dde
# post  a9a97d8366303af830c81363bfe2ef34
#
#                                                      id
# post  2020-7-13-16_01-COVID-world-en_generic_COVID_E...
# post  2020-7-13-15_01-COVID-world-en_generic_COVID_E...
# post  2020-7-13-14_01-COVID-world-en_generic_COVID_E...
# post  2020-7-13-13_01-COVID-world-en_generic_COVID_E...
# post  2020-7-13-12_01-COVID-world-en_generic_COVID_E...
# ...                                                 ...
# post  2020-5-28-16_01-COVID-world-en_generic_COVID_E...
# post  2020-5-28-15_01-COVID-world-en_generic_COVID_E...
# post  2020-5-28-14_01-COVID-world-en_generic_COVID_E...
# post  2020-5-28-13_01-COVID-world-en_generic_COVID_E...
# post  2020-5-28-12_01-COVID-world-en_generic_COVID_E...
#
# [1000 rows x 14 columns]

# %% [markdown]
# ### Data Mining & Data Wrangling
# As you can see, there are jsons inside the original json. For that, we have to mining the json (data mining) to be able to use it correctly (data wrangling).
#
# How do you solve this issue? Research about this and try a solution.

# %%
# your code...

# %%
df_json.reset_index(inplace = True)

# %%
df_json.head()
# Out:
#                                                 data
# 0  [{'date': '2020-07-13T16:03:32+02:00', 'metada...

# %%
df_json.columns
# Out:
# Index(['index', 'data'], dtype='object')

# %%
df_json.drop('index', axis = 1, inplace = True)

# %%
df_json.head()
# Out:
#                                                 data
# 0  [{'date': '2020-07-13T16:03:32+02:00', 'metada...

# %%
lista_total = []
diccionario_df = {}
for lista_json in df_json.data: 
    for json in lista_json: 
        for key, value in json.items():
            if key not in diccionario_df.keys():
               diccionario_df[key] = [value]

# %%
diccionario_df
# Out:
# {'date': ['2020-07-13T16:03:32+02:00'],
#  'metadata': [{'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=253%2C908&actives_num=216%2C926&recovered_num=8%2C579&deaths_num=28%2C403&date=13%20de%20julio%20del%202020&region=spain&aspect_ratio=square&client=default',
#    'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=253%2C908&confirmed_today_num=0&deaths_today_num=0&deaths_num=28%2C403&date=13%20de%20julio%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#    'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#     'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#     'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#     'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#     'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#     'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#     'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#     'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#     'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#     'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#     'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#     'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#     'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#     'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#     'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#     'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#     'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#    'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=12%2C872%2C896&actives_num=5%2C321%2C893&recovered_num=6%2C992%2C487&deaths_num=558%2C516&date=13%20de%20julio%20del%202020&region=world&aspect_ratio=square&client=default',
#    'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=12%2C872%2C896&deaths_num=558%2C516&date=13%20de%20julio%20del%202020&top_countries=EE.UU.%20%283%2C304%2C942%29%2C%20Brasil%20%281%2C864%2C681%29%2C%20India%20%28879%2C366%29&top_spain=Madrid%20%2872%2C532%29%2C%20Catalu%C3%B1a%20%2863%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2819%2C787%29&region=spain&aspect_ratio=16_9&client=default',
#    'composition_type': 'world',
#    'country_selected': None,
#    'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=12%2C872%2C896&actives_num=5%2C321%2C893&recovered_num=6%2C992%2C487&deaths_num=558%2C516&date=13%20de%20julio%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#    'state_selected': None}],
#  'author': ['Narrativa'],
#  '_rev': ['1-dcca4c2578b878b87e8fe6035d232424'],
#  'language': ['en_generic'],
#  'title': ['Coronavirus outbreak latest: <strong>1,282</strong> new deaths reported worldwide'],
#  'content': ['<p><small>Narrativa | Monday, July 13, 2020 </small></p><p>There are now <strong>12,872,896</strong> <strong>people infected worldwide</strong>, with <strong>6,992,487</strong></strong> of these having already recovered, according to the data <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">provided by Johns Hopkins University</a>. <b>The US</b> tops the list with <strong>3,304,942</strong> recorded cases, followed by <b> Brazil</b>, <b> India</b>, and <b> Russia</b> with <strong>1,864,681, 879,366, and 732,547</strong> cases respectively.</p><h4>COVID-19 Status Worldwide</h4><p><table width="100%"><thead><tr><th><strong>Active Cases</strong></th><th colspan="2"><strong>Infected</strong></th><th colspan="2"><strong>Deaths</strong></th><th colspan="2"><strong>Recovered</strong></th></tr><tr><th>Total</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th></tr></thead><tbody><tr><td>1. The US: 2,163,411</td><td>1. The US: 3,304,942</td><td>1. Russia: 6,511</td><td>1. The US: 135,205</td><td>1. Mexico: 276</td><td>1. Brazil: 1,264,843</strong></td><td>1. Brazil: 20,755</strong></td></tr><tr><td>2. Brazil: 527,738</td><td>2. Brazil: 1,864,681</td><td>2. Mexico: 4,482</td><td>2. Brazil: 72,100</td><td>2. Philippines: 227</td><td>2. The US: 1,006,326</strong></td><td>2. Philippines: 6,334</strong></td></tr><tr><td>3. India: 301,748</td><td>3. India: 879,366</td><td>3. The US: 3,122</td><td>3. The United Kingdom: 44,904</td><td>3. Iran: 203</td><td>3. India: 554,430</strong></td><td>3. Pakistan: 5,217</strong></td></tr></tbody></table></p><p>During the last 24 hours, there has been a <strong>0.32</strong>% increase with <strong>41,175</strong> new cases. <strong> Russia</strong> is the country that has confirmed the highest number of new cases with <strong>6,511</strong>, followed by <b> Mexico</b> with <strong>4,482</strong>. <strong>The US</strong> and <strong> Bangladesh</strong> are not far behind, with <strong>3,122</strong> and <strong>3,099</strong> new cases respectively.</p><p> </p><p>Since the beginning, <strong>the total number of deceased by coronavirus worldwide</strong> is <strong>558,516 people</strong>, including the <strong>1,282</strong> new deaths over last 24 hours. <strong>The US</strong> has registered the most victims so far with <strong>135,205</strong> deaths, followed by <strong> Brazil, The United Kingdom, and Mexico</strong> with <strong>72,100, 44,904, and 35,006</strong> deaths respectively.</p><p>The first signs of the virus appeared in <strong>China</strong>, in the city of <strong>Wuhan</strong>, on <strong>31 December 2019</strong>. Since that date, the number of infections have multiplied across the continent and the world. At the moment, cases in China have grown to <strong>8</strong> new cases since yesterday. Overall, <strong>569</strong> people are infected with the virus.</p><hr><p><strong>Note</strong>: This article has been <strong><u>generated automatically by <a href="https://www.narrativa.com" target="_blank">Narrativa</a></u></strong> from the data by <a href="https://github.com/pcm-dpc/COVID-19" target="_blank">Dipartimento della Protezione Civile de Italia</a>, <a href="https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Situationsberichte/Gesamt.html" target="_blank">Robert Koch Institute</a> and <a href="https://www.arcgis.com/apps/opsdashboard/index.html#/bda7594740fd40299423467b48e9ecf6" target="_blank">Johns Hopkins University</a>.</p>'],
#  'picurl_world': ['https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=12%2C872%2C896&actives_num=5%2C321%2C893&recovered_num=6%2C992%2C487&deaths_num=558%2C516&date=13%20de%20julio%20del%202020&top_paises1=EE.UU.%3A%203%2C304%2C942&top_paises2=Brasil%3A%201%2C864%2C681&top_paises3=India%3A%20879%2C366&client=default&region=world'],
#  'picurl': ['https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=253%2C908&confirmed_today_num=0&deaths_today_num=0&deaths_num=28%2C403&date=13%20de%20julio%20del%202020&top_comunidades=Madrid%20%2872%2C532%29%2C%20Catalu%C3%B1a%20%2863%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2819%2C787%29&client=default&region=spain'],
#  'metatitle': [''],
#  'subtitle': [''],
#  'picurl_banner_web': ['https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=12%2C872%2C896&actives_num=5%2C321%2C893&recovered_num=6%2C992%2C487&deaths_num=558%2C516&region_confirmed_num=253%2C908&region_confirmed_today_num=0&region_deaths_today_num=0&region_deaths_num=28%2C403&date=13%20de%20julio%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=India&top_paises1_num=3%2C304%2C942&top_paises2_num=1%2C864%2C681&top_paises3_num=879%2C366&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=72%2C532&top_comunidades2_num=63%2C888&top_comunidades3_num=19%2C787&gen_date=2020/07/13&gen_time=16%3A00&client=default_web&region=world'],
#  '_id': ['95a8dfdaec69cd5225aad0c2ef6d4c87'],
#  'id': ['2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC']}

# %%
lista_total[0]
# Out:
# {'date': '2020-07-13T16:03:32+02:00',
#  'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=253%2C908&actives_num=216%2C926&recovered_num=8%2C579&deaths_num=28%2C403&date=13%20de%20julio%20del%202020&region=spain&aspect_ratio=square&client=default',
#   'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=253%2C908&confirmed_today_num=0&deaths_today_num=0&deaths_num=28%2C403&date=13%20de%20julio%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#   'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#    'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#    'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#    'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#    'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#    'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#    'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#    'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#    'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#    'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#    'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#    'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#    'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#    'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#    'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#    'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#    'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#   'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=12%2C872%2C896&actives_num=5%2C321%2C893&recovered_num=6%2C992%2C487&deaths_num=558%2C516&date=13%20de%20julio%20del%202020&region=world&aspect_ratio=square&client=default',
#   'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=12%2C872%2C896&deaths_num=558%2C516&date=13%20de%20julio%20del%202020&top_countries=EE.UU.%20%283%2C304%2C942%29%2C%20Brasil%20%281%2C864%2C681%29%2C%20India%20%28879%2C366%29&top_spain=Madrid%20%2872%2C532%29%2C%20Catalu%C3%B1a%20%2863%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2819%2C787%29&region=spain&aspect_ratio=16_9&client=default',
#   'composition_type': 'world',
#   'country_selected': None,
#   'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=12%2C872%2C896&actives_num=5%2C321%2C893&recovered_num=6%2C992%2C487&deaths_num=558%2C516&date=13%20de%20julio%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#   'state_selected': None},
#  'author': 'Narrativa',
#  '_rev': '1-dcca4c2578b878b87e8fe6035d232424',
#  'language': 'en_generic',
#  'title': 'Coronavirus outbreak latest: <strong>1,282</strong> new deaths reported worldwide',
#  'content': '<p><small>Narrativa | Monday, July 13, 2020 </small></p><p>There are now <strong>12,872,896</strong> <strong>people infected worldwide</strong>, with <strong>6,992,487</strong></strong> of these having already recovered, according to the data <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">provided by Johns Hopkins University</a>. <b>The US</b> tops the list with <strong>3,304,942</strong> recorded cases, followed by <b> Brazil</b>, <b> India</b>, and <b> Russia</b> with <strong>1,864,681, 879,366, and 732,547</strong> cases respectively.</p><h4>COVID-19 Status Worldwide</h4><p><table width="100%"><thead><tr><th><strong>Active Cases</strong></th><th colspan="2"><strong>Infected</strong></th><th colspan="2"><strong>Deaths</strong></th><th colspan="2"><strong>Recovered</strong></th></tr><tr><th>Total</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th></tr></thead><tbody><tr><td>1. The US: 2,163,411</td><td>1. The US: 3,304,942</td><td>1. Russia: 6,511</td><td>1. The US: 135,205</td><td>1. Mexico: 276</td><td>1. Brazil: 1,264,843</strong></td><td>1. Brazil: 20,755</strong></td></tr><tr><td>2. Brazil: 527,738</td><td>2. Brazil: 1,864,681</td><td>2. Mexico: 4,482</td><td>2. Brazil: 72,100</td><td>2. Philippines: 227</td><td>2. The US: 1,006,326</strong></td><td>2. Philippines: 6,334</strong></td></tr><tr><td>3. India: 301,748</td><td>3. India: 879,366</td><td>3. The US: 3,122</td><td>3. The United Kingdom: 44,904</td><td>3. Iran: 203</td><td>3. India: 554,430</strong></td><td>3. Pakistan: 5,217</strong></td></tr></tbody></table></p><p>During the last 24 hours, there has been a <strong>0.32</strong>% increase with <strong>41,175</strong> new cases. <strong> Russia</strong> is the country that has confirmed the highest number of new cases with <strong>6,511</strong>, followed by <b> Mexico</b> with <strong>4,482</strong>. <strong>The US</strong> and <strong> Bangladesh</strong> are not far behind, with <strong>3,122</strong> and <strong>3,099</strong> new cases respectively.</p><p> </p><p>Since the beginning, <strong>the total number of deceased by coronavirus worldwide</strong> is <strong>558,516 people</strong>, including the <strong>1,282</strong> new deaths over last 24 hours. <strong>The US</strong> has registered the most victims so far with <strong>135,205</strong> deaths, followed by <strong> Brazil, The United Kingdom, and Mexico</strong> with <strong>72,100, 44,904, and 35,006</strong> deaths respectively.</p><p>The first signs of the virus appeared in <strong>China</strong>, in the city of <strong>Wuhan</strong>, on <strong>31 December 2019</strong>. Since that date, the number of infections have multiplied across the continent and the world. At the moment, cases in China have grown to <strong>8</strong> new cases since yesterday. Overall, <strong>569</strong> people are infected with the virus.</p><hr><p><strong>Note</strong>: This article has been <strong><u>generated automatically by <a href="https://www.narrativa.com" target="_blank">Narrativa</a></u></strong> from the data by <a href="https://github.com/pcm-dpc/COVID-19" target="_blank">Dipartimento della Protezione Civile de Italia</a>, <a href="https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Situationsberichte/Gesamt.html" target="_blank">Robert Koch Institute</a> and <a href="https://www.arcgis.com/apps/opsdashboard/index.html#/bda7594740fd40299423467b48e9ecf6" target="_blank">Johns Hopkins University</a>.</p>',
#  'picurl_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=12%2C872%2C896&actives_num=5%2C321%2C893&recovered_num=6%2C992%2C487&deaths_num=558%2C516&date=13%20de%20julio%20del%202020&top_paises1=EE.UU.%3A%203%2C304%2C942&top_paises2=Brasil%3A%201%2C864%2C681&top_paises3=India%3A%20879%2C366&client=default&region=world',
#  'picurl': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=253%2C908&confirmed_today_num=0&deaths_today_num=0&deaths_num=28%2C403&date=13%20de%20julio%20del%202020&top_comunidades=Madrid%20%2872%2C532%29%2C%20Catalu%C3%B1a%20%2863%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2819%2C787%29&client=default&region=spain',
#  'metatitle': '',
#  'subtitle': '',
#  'picurl_banner_web': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=12%2C872%2C896&actives_num=5%2C321%2C893&recovered_num=6%2C992%2C487&deaths_num=558%2C516&region_confirmed_num=253%2C908&region_confirmed_today_num=0&region_deaths_today_num=0&region_deaths_num=28%2C403&date=13%20de%20julio%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=India&top_paises1_num=3%2C304%2C942&top_paises2_num=1%2C864%2C681&top_paises3_num=879%2C366&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=72%2C532&top_comunidades2_num=63%2C888&top_comunidades3_num=19%2C787&gen_date=2020/07/13&gen_time=16%3A00&client=default_web&region=world',
#  '_id': '95a8dfdaec69cd5225aad0c2ef6d4c87',
#  'id': '2020-7-13-16_01-COVID-world-en_generic_COVID_EN_GENERIC'}
