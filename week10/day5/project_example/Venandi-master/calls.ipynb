# %%
import requests

# %% [markdown]
# ### API Connect

# %%
url = "http://localhost:3500/"
requests.get(url).json()
# Out:
# {'Hello welcome to Venandi! This API has 2 basic tasks': {'1': {'Find Github users by location, programming language and seniority: to perform this query use the following command': '/user/<location>/<language>/<seniority>/get'},
#   '2': {'Predict the seniority of the selected user': 'to perform this query use the following command: /user/<login>/predict'}}}

# %% [markdown]
# ### Get Users from Github

# %%
url = f"http://localhost:3500/user/madrid/jupyter/principal/get"

data = requests.get(url).text
print(data)
# Out:
# {
#   "0": {
#     "1. Name": "Marc Pomar Torres",
#     "2. Company": "Faable",
#     "3. Location": "Madrid, Spain",
#     "4. Email": "marc@faable.com",
#     "5. Hireable": true,
#     "6. Number of Repositories": 52,
#     "7. Number of Followers": 249,
#     "8. Account Created at": "2011-01-17T10:32:14Z",
#     "9. Account Updated at": "2020-05-11T14:29:15Z"
#   },
#   "1": {
#     "1. Name": "javi santana",
#     "2. Company": null,
#     "3. Location": "Madrid",
#     "4. Email": null,
#     "5. Hireable": null,
#     "6. Number of Repositories": 78,
#     "7. Number of Followers": 245,
#     "8. Account Created at": "2008-10-21T14:09:08Z",
#     "9. Account Updated at": "2020-03-11T11:42:43Z"
#   },
#   "2": {
#     "1. Name": "Carlos Garcia Saura",
#     "2. Company": null,
#     "3. Location": "Madrid, Spain",
#     "4. Email": null,
#     "5. Hireable": null,
#     "6. Number of Repositories": 39,
#     "7. Number of Followers": 245,
# ...

# %% [markdown]
# ### Predict User Seniority

# %%
url = f"http://localhost:3500/user/ferrero-felipe/predict"

data = requests.get(url).text
print(data)
# Out:
# {
#   "Github Seniority": {
#     "Felipe Ferrero": "middle"
#   },
#   "Linkedin Profile Link & could happen Social Media links": {
#     "0": "https://es.linkedin.com/in/ferrero-felipe",
#     "1": "https://www.linkedin.com/pub/dir/Felipe/Ferrero",
#     "2": "https://es.linkedin.com/in/felipe-ferrero-3441628b",
#     "3": "https://ar.linkedin.com/in/felipe-ferrero-7a2200151"
#   }
# }
