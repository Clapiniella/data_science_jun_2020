# %% [markdown]
# 1. En primer lugar se le da un valor numérico diferente a cada palabra o símbolo
# 2. Cuando se ha dado un valor numérico a cada palabra o símbolo (puede ser un array one-hot), se pasa a un embedding (múltiples formas). En este caso, vamos a ver CBOW y Skip-Gram
# 3. La red neuronal va a otorgar una serie de pesos a la palabra, que representa la codificación (vector) de la palabra.
# 4. A partir de ese vector, se puede medir la "distancia" que existe entre cada palabra.
# 5. El entrenamiento trata de ajustar los pesos para representar mejor el vector de cada palabra.
# 6. https://projector.tensorflow.org/

# %% [markdown]
# ![](to_number.png)
#
# A vector o número incremental:
#
# perro: 0
#
# gato: 1
#
# mi: 2
#
# ...

# %% [markdown]
# Trabaja con una ventana
#
# ![](window_vector.png)

# %% [markdown]
# ![](CBOW_Skip_gram.png)

# %%
# Python program to generate word vectors using Word2Vec 

# importing all necessary modules 
from nltk.tokenize import sent_tokenize, word_tokenize 
import warnings 
import nltk

nltk.download('punkt')

warnings.filterwarnings(action = 'ignore') 

import gensim 
from gensim.models import Word2Vec 

# pip3 install nltk
# pip3 install gensim
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\gvazquez\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Reads 'la_ultima_pregunta.txt' file 
sample = open("la_ultima_pregunta.txt", "r", encoding="utf8") 
s = sample.read() 

# Replaces escape character with space 
f = s.replace("\n", " ") 
data = [] 
# Preprocessing

# iterate through each sentence in the file 
for i in sent_tokenize(f): 
    temp = [] 
    print("i:", i)
    # tokenize the sentence into words 
    for j in word_tokenize(i): 
        temp.append(j.lower()) 
        print("j:", j)
    data.append(temp)
# Out:
# i: La última pregunta se formuló por primera vez, medio en broma, el 21 de mayo de 2061, en momentos en que la humanidad (también por primera vez) se bañó en luz.
# j: La
# j: última
# j: pregunta
# j: se
# j: formuló
# j: por
# j: primera
# j: vez
# j: ,
# j: medio
# j: en
# j: broma
# j: ,
# j: el
# j: 21
# j: de
# j: mayo
# j: de
# j: 2061
# j: ,
# j: en
# j: momentos
# j: en
# j: que
# j: la
# j: humanidad
# j: (
# j: también
# j: por
# j: primera
# j: vez
# j: )
# j: se
# j: bañó
# j: en
# j: luz
# j: .
# i: La pregunta llegó como resultado de una apuesta por cinco dólares hecha entre dos hombres que bebían cerveza, y sucedió de esta manera: Alexander Adell y Bertram Lupov eran dos de los fieles asistentes de Multivac.
# j: La
# j: pregunta
# j: llegó
# j: como
# j: resultado
# j: de
# j: una
# j: apuesta
# j: por
# j: cinco
# j: dólares
# j: hecha
# j: entre
# j: dos
# j: hombres
# j: que
# j: bebían
# j: cerveza
# j: ,
# j: y
# j: sucedió
# j: de
# j: esta
# j: manera
# j: :
# j: Alexander
# j: Adell
# j: y
# j: Bertram
# j: Lupov
# j: eran
# j: dos
# j: de
# j: los
# j: fieles
# j: asistentes
# j: de
# j: Multivac
# j: .
# i: Dentro de las dimensiones de lo humano sabían qué era lo que pasaba detrás del rostro frío, parpadeante e intermitentemente luminoso -kilómetros y kilómetros de rostro- de la gigantesca computadora.
# j: Dentro
# j: de
# j: las
# j: dimensiones
# j: de
# j: lo
# j: humano
# j: sabían
# j: qué
# j: era
# j: lo
# j: que
# j: pasaba
# j: detrás
# j: del
# j: rostro
# j: frío
# j: ,
# j: parpadeante
# j: e
# j: intermitentemente
# j: luminoso
# j: -kilómetros
# j: y
# j: kilómetros
# j: de
# j: rostro-
# j: de
# j: la
# j: gigantesca
# j: computadora
# j: .
# i: Al menos tenían una vaga noción del plan general de circuitos y retransmirores que desde hacía mucho tiempo habían superado toda posibilidad de ser dominados por una sola persona.
# j: Al
# j: menos
# j: tenían
# j: una
# j: vaga
# j: noción
# j: del
# j: plan
# j: general
# j: de
# j: circuitos
# j: y
# j: retransmirores
# j: que
# j: desde
# j: hacía
# j: mucho
# j: tiempo
# j: habían
# j: superado
# j: toda
# j: posibilidad
# j: de
# j: ser
# j: dominados
# j: por
# j: una
# j: sola
# j: persona
# j: .
# i: Multivac se autoajustaba y autocorregía.
# j: Multivac
# j: se
# j: autoajustaba
# j: y
# j: autocorregía
# j: .
# i: Así tenía que ser, porque nada que fuera humano podía ajustarla y corregirla con la rapidez suficiente o siquiera con la eficacia suficiente.
# j: Así
# j: tenía
# j: que
# j: ser
# j: ,
# j: porque
# j: nada
# j: que
# j: fuera
# j: humano
# j: podía
# j: ajustarla
# j: y
# j: corregirla
# j: con
# j: la
# j: rapidez
# j: suficiente
# j: o
# j: siquiera
# j: con
# j: la
# j: eficacia
# j: suficiente
# j: .
# i: De manera que Adell y Lupov atendían al monstruoso gigante sólo en forma ligera y superficial, pero lo hacían tan bien como podría hacerlo cualquier otro hombre.
# j: De
# j: manera
# j: que
# j: Adell
# j: y
# j: Lupov
# j: atendían
# j: al
# j: monstruoso
# j: gigante
# j: sólo
# j: en
# j: forma
# j: ligera
# j: y
# j: superficial
# j: ,
# j: pero
# j: lo
# j: hacían
# j: tan
# j: bien
# j: como
# j: podría
# j: hacerlo
# j: cualquier
# j: otro
# j: hombre
# j: .
# i: La alimentaban con información, adaptaban las preguntas a sus necesidades y traducían las respuestas que aparecían.
# j: La
# j: alimentaban
# j: con
# j: información
# j: ,
# j: adaptaban
# j: las
# j: preguntas
# j: a
# j: sus
# j: necesidades
# j: y
# j: traducían
# j: las
# j: respuestas
# j: que
# j: aparecían
# j: .
# i: Por cierto, ellos, y todos los demás asistentes tenían pleno derecho a compartir la gloria de Multivac.
# j: Por
# j: cierto
# j: ,
# j: ellos
# j: ,
# j: y
# j: todos
# j: los
# j: demás
# j: asistentes
# j: tenían
# j: pleno
# j: derecho
# j: a
# j: compartir
# j: la
# j: gloria
# j: de
# j: Multivac
# j: .
# i: Durante décadas, Multivac ayudó a diseñar naves y a trazar las trayectorias que permitieron al hombre llegar a la Luna, a Marte y a Venus, pero después de eso, los pobres recursos de la Tierra ya no pudieron serles de utilidad a las naves.
# j: Durante
# j: décadas
# j: ,
# j: Multivac
# j: ayudó
# j: a
# j: diseñar
# j: naves
# j: y
# j: a
# j: trazar
# j: las
# j: trayectorias
# j: que
# j: permitieron
# j: al
# j: hombre
# j: llegar
# j: a
# j: la
# j: Luna
# j: ,
# j: a
# j: Marte
# j: y
# j: a
# j: Venus
# j: ,
# j: pero
# j: después
# j: de
# j: eso
# j: ,
# j: los
# j: pobres
# j: recursos
# j: de
# j: la
# j: Tierra
# j: ya
# j: no
# j: pudieron
# j: serles
# j: de
# j: utilidad
# j: a
# j: las
# j: naves
# j: .
# i: Se necesitaba demasiada energía para los viajes largos y pese a que la Tierra explotaba su carbón y uranio con creciente eficacia había una cantidad limitada de ambos.
# j: Se
# j: necesitaba
# j: demasiada
# j: energía
# j: para
# j: los
# j: viajes
# j: largos
# j: y
# j: pese
# j: a
# j: que
# j: la
# j: Tierra
# j: explotaba
# j: su
# j: carbón
# j: y
# j: uranio
# j: con
# j: creciente
# j: eficacia
# j: había
# j: una
# j: cantidad
# j: limitada
# j: de
# j: ambos
# j: .
# i: Pero lentamente, Multivac aprendió lo suficiente como para responder a las preguntas más complejas en forma más profunda, y el 14 de mayo de 2061 lo que hasta ese momento era teoría se convirtió en realidad.
# j: Pero
# j: lentamente
# j: ,
# j: Multivac
# j: aprendió
# j: lo
# j: suficiente
# j: como
# j: para
# j: responder
# j: a
# j: las
# j: preguntas
# j: más
# j: complejas
# j: en
# j: forma
# j: más
# j: profunda
# j: ,
# j: y
# j: el
# j: 14
# j: de
# j: mayo
# j: de
# j: 2061
# j: lo
# j: que
# j: hasta
# j: ese
# j: momento
# j: era
# j: teoría
# j: se
# j: convirtió
# j: en
# j: realidad
# j: .
# i: La energía del Sol fue almacenada, modificada y utilizada directamente en todo el planeta.
# j: La
# j: energía
# j: del
# j: Sol
# j: fue
# j: almacenada
# j: ,
# j: modificada
# j: y
# j: utilizada
# j: directamente
# j: en
# j: todo
# j: el
# j: planeta
# j: .
# i: Cesó en todas partes el hábito de quemar carbón y fisionar uranio y toda la Tierra se conectó con una pequeña estación -de un kilómetro y medio de diámetro- que circundaba el planeta a mitad de distancia de la Luna, para funcionar con rayos invisibles de energía solar.
# j: Cesó
# j: en
# j: todas
# j: partes
# j: el
# j: hábito
# j: de
# j: quemar
# j: carbón
# j: y
# j: fisionar
# j: uranio
# j: y
# j: toda
# j: la
# j: Tierra
# j: se
# j: conectó
# j: con
# j: una
# j: pequeña
# j: estación
# j: -de
# j: un
# j: kilómetro
# j: y
# j: medio
# j: de
# j: diámetro-
# j: que
# j: circundaba
# j: el
# j: planeta
# j: a
# j: mitad
# j: de
# j: distancia
# j: de
# j: la
# j: Luna
# j: ,
# j: para
# j: funcionar
# j: con
# j: rayos
# j: invisibles
# j: de
# j: energía
# j: solar
# j: .
# i: Siete días no habían alcanzado para empañar la gloria del acontecimiento, y Adell y Lupov finalmente lograron escapar de la celebración pública, para refugiarse donde nadie pensaría en buscarlos: en las desiertas cámaras subterráneas, donde se veían partes del poderoso cuerpo enterrado de Multivac.
# j: Siete
# j: días
# j: no
# j: habían
# j: alcanzado
# j: para
# j: empañar
# j: la
# j: gloria
# j: del
# j: acontecimiento
# j: ,
# j: y
# j: Adell
# j: y
# j: Lupov
# j: finalmente
# j: lograron
# j: escapar
# j: de
# j: la
# j: celebración
# j: pública
# j: ,
# j: para
# j: refugiarse
# j: donde
# j: nadie
# j: pensaría
# j: en
# j: buscarlos
# j: :
# j: en
# j: las
# j: desiertas
# j: cámaras
# j: subterráneas
# j: ,
# j: donde
# j: se
# j: veían
# j: partes
# j: del
# j: poderoso
# j: cuerpo
# j: enterrado
# j: de
# j: Multivac
# j: .
# i: Sin asistentes, ociosa, clasificando datos con clicks satisfechos y perezosos, Multivac también se había  2 ganado sus vacaciones y los asistentes la respetaban y originalmente no tenían intención de perturbarla.
# j: Sin
# j: asistentes
# j: ,
# j: ociosa
# j: ,
# j: clasificando
# j: datos
# j: con
# j: clicks
# j: satisfechos
# j: y
# j: perezosos
# j: ,
# j: Multivac
# j: también
# j: se
# j: había
# j: 2
# j: ganado
# j: sus
# j: vacaciones
# j: y
# j: los
# j: asistentes
# j: la
# j: respetaban
# j: y
# j: originalmente
# j: no
# j: tenían
# j: intención
# j: de
# j: perturbarla
# j: .
# i: Se habían llevado una botella, y su única preocupación en ese momento era relajarse y disfrutar de la bebida.
# j: Se
# j: habían
# j: llevado
# j: una
# j: botella
# j: ,
# j: y
# j: su
# j: única
# j: preocupación
# j: en
# j: ese
# j: momento
# j: era
# j: relajarse
# j: y
# j: disfrutar
# j: de
# j: la
# j: bebida
# j: .
# i: - Es asombroso, cuando uno lo piensa -dijo Adell.
# j: -
# j: Es
# j: asombroso
# j: ,
# j: cuando
# j: uno
# j: lo
# j: piensa
# j: -dijo
# j: Adell
# j: .
# i: En su rostro ancho se veían huellas de cansancio, y removió lentamente la bebida con una varilla de vidrio, observando el movimiento de los cubos de hielo en su interior.
# j: En
# j: su
# j: rostro
# j: ancho
# j: se
# j: veían
# j: huellas
# j: de
# j: cansancio
# j: ,
# j: y
# j: removió
# j: lentamente
# j: la
# j: bebida
# j: con
# j: una
# j: varilla
# j: de
# j: vidrio
# j: ,
# j: observando
# j: el
# j: movimiento
# j: de
# j: los
# j: cubos
# j: de
# j: hielo
# j: en
# j: su
# j: interior
# j: .
# i: - Toda la energía que podremos usar de ahora en adelante, gratis.
# j: -
# j: Toda
# j: la
# j: energía
# j: que
# j: podremos
# j: usar
# j: de
# j: ahora
# j: en
# j: adelante
# j: ,
# j: gratis
# j: .
# i: Suficiente energía, si quisiéramos emplearla, como para derretir a toda la Tierra y convertirla en una enorme gota de hierro líquido impuro, y no echar de menos la energía empleada.
# j: Suficiente
# j: energía
# j: ,
# j: si
# j: quisiéramos
# j: emplearla
# j: ,
# j: como
# j: para
# j: derretir
# j: a
# j: toda
# j: la
# j: Tierra
# j: y
# j: convertirla
# j: en
# j: una
# j: enorme
# j: gota
# j: de
# j: hierro
# j: líquido
# j: impuro
# j: ,
# j: y
# j: no
# j: echar
# j: de
# j: menos
# j: la
# j: energía
# j: empleada
# j: .
# i: Toda la energía que podremos usar por siempre y siempre y siempre.
# j: Toda
# j: la
# j: energía
# j: que
# j: podremos
# j: usar
# j: por
# j: siempre
# j: y
# j: siempre
# j: y
# j: siempre
# j: .
# i: Lupov ladeó la cabeza.
# j: Lupov
# j: ladeó
# j: la
# j: cabeza
# j: .
# i: Tenía el hábito de hacerlo cuando quería oponerse a lo que oía, y en ese momento quería oponerse; en parte porque había tenido que llevar el hielo y los vasos.
# j: Tenía
# j: el
# j: hábito
# j: de
# j: hacerlo
# j: cuando
# j: quería
# j: oponerse
# j: a
# j: lo
# j: que
# j: oía
# j: ,
# j: y
# j: en
# j: ese
# j: momento
# j: quería
# j: oponerse
# j: ;
# j: en
# j: parte
# j: porque
# j: había
# j: tenido
# j: que
# j: llevar
# j: el
# j: hielo
# j: y
# j: los
# j: vasos
# j: .
# i: - No para siempre -dijo.
# j: -
# j: No
# j: para
# j: siempre
# j: -dijo
# j: .
# i: - Ah, vamos, prácticamente para siempre.
# j: -
# j: Ah
# j: ,
# j: vamos
# j: ,
# j: prácticamente
# j: para
# j: siempre
# j: .
# i: Hasta que el Sol se apague, Bert.
# j: Hasta
# j: que
# j: el
# j: Sol
# j: se
# j: apague
# j: ,
# j: Bert
# j: .
# i: - Entonces no es para siempre.
# j: -
# j: Entonces
# j: no
# j: es
# j: para
# j: siempre
# j: .
# i: - Muy bien, entonces.
# j: -
# j: Muy
# j: bien
# j: ,
# j: entonces
# j: .
# i: Durante miles de millones de años.
# j: Durante
# j: miles
# j: de
# j: millones
# j: de
# j: años
# j: .
# i: Veinte mil millones, tal vez.
# j: Veinte
# j: mil
# j: millones
# j: ,
# j: tal
# j: vez
# j: .
# i: ¿Estás satisfecho?
# j: ¿Estás
# j: satisfecho
# j: ?
# i: Lupov se pasó los dedos por los escasos cabellos como para asegurarse de que todavía le quedaban algunos y tomó un pequeño sorbo de su bebida.
# j: Lupov
# j: se
# j: pasó
# j: los
# j: dedos
# j: por
# j: los
# j: escasos
# j: cabellos
# j: como
# j: para
# j: asegurarse
# j: de
# j: que
# j: todavía
# j: le
# j: quedaban
# j: algunos
# j: y
# j: tomó
# j: un
# j: pequeño
# j: sorbo
# j: de
# j: su
# j: bebida
# j: .
# i: - Veinte mil millones de años no es &#39;para siempre&#39;.
# j: -
# j: Veinte
# j: mil
# j: millones
# j: de
# j: años
# j: no
# j: es
# j: &#39;para
# j: siempre
# j: &#39;
# j: .
# i: - Bien, pero superará nuestra época ¿verdad?
# j: -
# j: Bien
# j: ,
# j: pero
# j: superará
# j: nuestra
# j: época
# j: ¿verdad
# j: ?
# i: - También la superarán el carbón y el uranio.
# j: -
# j: También
# j: la
# j: superarán
# j: el
# j: carbón
# j: y
# j: el
# j: uranio
# j: .
# i: - De acuerdo, pero ahora podemos conectar cada nave espacial individualmente con la Estación Solar, y hacer que vaya y regrese de Plutón un millón de veces sin que tengamos que preocuparnos por el combustible.
# j: -
# j: De
# j: acuerdo
# j: ,
# j: pero
# j: ahora
# j: podemos
# j: conectar
# j: cada
# j: nave
# j: espacial
# j: individualmente
# j: con
# j: la
# j: Estación
# j: Solar
# j: ,
# j: y
# j: hacer
# j: que
# j: vaya
# j: y
# j: regrese
# j: de
# j: Plutón
# j: un
# j: millón
# j: de
# j: veces
# j: sin
# j: que
# j: tengamos
# j: que
# j: preocuparnos
# j: por
# j: el
# j: combustible
# j: .
# i: No puedes hacer eso con carbón y uranio.
# j: No
# j: puedes
# j: hacer
# j: eso
# j: con
# j: carbón
# j: y
# j: uranio
# j: .
# i: Pregúntale a Multivac, si no me crees.
# j: Pregúntale
# j: a
# j: Multivac
# j: ,
# j: si
# j: no
# j: me
# j: crees
# j: .
# i: - No necesito preguntarle a Multivac.
# j: -
# j: No
# j: necesito
# j: preguntarle
# j: a
# j: Multivac
# j: .
# i: Lo sé.
# j: Lo
# j: sé
# j: .
# i: - Entonces deja de quitarle méritos a lo que Multivac ha hecho por nosotros -dijo Adell, malhumorado-.
# j: -
# j: Entonces
# j: deja
# j: de
# j: quitarle
# j: méritos
# j: a
# j: lo
# j: que
# j: Multivac
# j: ha
# j: hecho
# j: por
# j: nosotros
# j: -dijo
# j: Adell
# j: ,
# j: malhumorado-
# j: .
# i: Se portó muy bien.
# j: Se
# j: portó
# j: muy
# j: bien
# j: .
# i: 3 - ¿Quién dice que no?
# j: 3
# j: -
# j: ¿Quién
# j: dice
# j: que
# j: no
# j: ?
# i: Lo que yo sostengo es que el Sol no durará eternamente.
# j: Lo
# j: que
# j: yo
# j: sostengo
# j: es
# j: que
# j: el
# j: Sol
# j: no
# j: durará
# j: eternamente
# j: .
# i: Eso es todo lo que digo.
# j: Eso
# j: es
# j: todo
# j: lo
# j: que
# j: digo
# j: .
# i: Estamos a salvo por veinte mil millones de años, pero ¿y luego?
# j: Estamos
# j: a
# j: salvo
# j: por
# j: veinte
# j: mil
# j: millones
# j: de
# j: años
# j: ,
# j: pero
# j: ¿y
# j: luego
# j: ?
# i: -Lupov apuntó con un dedo tembloroso al otro.
# j: -Lupov
# j: apuntó
# j: con
# j: un
# j: dedo
# j: tembloroso
# j: al
# j: otro
# j: .
# i: - Y no me digas que nos conectaremos con otro Sol.
# j: -
# j: Y
# j: no
# j: me
# j: digas
# j: que
# j: nos
# j: conectaremos
# j: con
# j: otro
# j: Sol
# j: .
# i: Durante un rato hubo silencio.
# j: Durante
# j: un
# j: rato
# j: hubo
# j: silencio
# j: .
# i: Adell se llevaba la copa a los labios sólo de vez en cuando, y los ojos de Lupov se cerraron lentamente.
# j: Adell
# j: se
# j: llevaba
# j: la
# j: copa
# j: a
# j: los
# j: labios
# j: sólo
# j: de
# j: vez
# j: en
# j: cuando
# j: ,
# j: y
# j: los
# j: ojos
# j: de
# j: Lupov
# j: se
# j: cerraron
# j: lentamente
# j: .
# i: Descansaron.
# j: Descansaron
# j: .
# i: De pronto Lupov abrió los ojos.
# j: De
# j: pronto
# j: Lupov
# j: abrió
# j: los
# j: ojos
# j: .
# i: - Piensas que nos conectaremos con otro Sol cuando el nuestro muera, ¿verdad?
# j: -
# j: Piensas
# j: que
# j: nos
# j: conectaremos
# j: con
# j: otro
# j: Sol
# j: cuando
# j: el
# j: nuestro
# j: muera
# j: ,
# j: ¿verdad
# j: ?
# i: - No estoy pensando nada.
# j: -
# j: No
# j: estoy
# j: pensando
# j: nada
# j: .
# i: - Seguro que estás pensando.
# j: -
# j: Seguro
# j: que
# j: estás
# j: pensando
# j: .
# i: Eres malo en lógica, ése es tu problema.
# j: Eres
# j: malo
# j: en
# j: lógica
# j: ,
# j: ése
# j: es
# j: tu
# j: problema
# j: .
# i: Eres como ese tipo del cuento a quien lo soprendió un chaparrón, corrió a refugiarse en un monte y se paró bajo un árbol.
# j: Eres
# j: como
# j: ese
# j: tipo
# j: del
# j: cuento
# j: a
# j: quien
# j: lo
# j: soprendió
# j: un
# j: chaparrón
# j: ,
# j: corrió
# j: a
# j: refugiarse
# j: en
# j: un
# j: monte
# j: y
# j: se
# j: paró
# j: bajo
# j: un
# j: árbol
# j: .
# i: No se preocupaba porque pensaba que cuando un árbol estuviera totalmente mojado, simplemente iría a guarecerse bajo otro.
# j: No
# j: se
# j: preocupaba
# j: porque
# j: pensaba
# j: que
# j: cuando
# j: un
# j: árbol
# j: estuviera
# j: totalmente
# j: mojado
# j: ,
# j: simplemente
# j: iría
# j: a
# j: guarecerse
# j: bajo
# j: otro
# j: .
# i: - Entiendo -dijo Adell-, no grites.
# j: -
# j: Entiendo
# j: -dijo
# j: Adell-
# j: ,
# j: no
# j: grites
# j: .
# i: Cuando el Sol muera, las otras estrellas habrán muerto también.
# j: Cuando
# j: el
# j: Sol
# j: muera
# j: ,
# j: las
# j: otras
# j: estrellas
# j: habrán
# j: muerto
# j: también
# j: .
# i: - Por supuesto -murmuró Lupov-.
# j: -
# j: Por
# j: supuesto
# j: -murmuró
# j: Lupov-
# j: .
# i: Todo comenzó con la explosión cósmica original, fuera lo que fuese, y todo terminará cuando todas las estrellas se extingan.
# j: Todo
# j: comenzó
# j: con
# j: la
# j: explosión
# j: cósmica
# j: original
# j: ,
# j: fuera
# j: lo
# j: que
# j: fuese
# j: ,
# j: y
# j: todo
# j: terminará
# j: cuando
# j: todas
# j: las
# j: estrellas
# j: se
# j: extingan
# j: .
# i: Algunas se agotan antes que otras.
# j: Algunas
# j: se
# j: agotan
# j: antes
# j: que
# j: otras
# j: .
# i: Por Dios, los gigantes no durarán cien millones de años.
# j: Por
# j: Dios
# j: ,
# j: los
# j: gigantes
# j: no
# j: durarán
# j: cien
# j: millones
# j: de
# j: años
# j: .
# i: El Sol durará veinte mil millones de años y tal vez las enanas durarán cien mil millones por mejores que sean.
# j: El
# j: Sol
# j: durará
# j: veinte
# j: mil
# j: millones
# j: de
# j: años
# j: y
# j: tal
# j: vez
# j: las
# j: enanas
# j: durarán
# j: cien
# j: mil
# j: millones
# j: por
# j: mejores
# j: que
# j: sean
# j: .
# i: Pero en un trillón de años estaremos a oscuras.
# j: Pero
# j: en
# j: un
# j: trillón
# j: de
# j: años
# j: estaremos
# j: a
# j: oscuras
# j: .
# i: La entropía tiene que incrementarse al máximo, eso es todo.
# j: La
# j: entropía
# j: tiene
# j: que
# j: incrementarse
# j: al
# j: máximo
# j: ,
# j: eso
# j: es
# j: todo
# j: .
# i: - Sé todo lo que hay que saber sobre la entropía -dijo Adell, tocado en su amor propio.
# j: -
# j: Sé
# j: todo
# j: lo
# j: que
# j: hay
# j: que
# j: saber
# j: sobre
# j: la
# j: entropía
# j: -dijo
# j: Adell
# j: ,
# j: tocado
# j: en
# j: su
# j: amor
# j: propio
# j: .
# i: - ¡Qué vas a saber!
# j: -
# j: ¡Qué
# j: vas
# j: a
# j: saber
# j: !
# i: - Sé tanto como tú.
# j: -
# j: Sé
# j: tanto
# j: como
# j: tú
# j: .
# i: - Entonces sabes que todo se extinguirá algún día.
# j: -
# j: Entonces
# j: sabes
# j: que
# j: todo
# j: se
# j: extinguirá
# j: algún
# j: día
# j: .
# i: - Muy bien.
# j: -
# j: Muy
# j: bien
# j: .
# i: ¿Quién dice que no?
# j: ¿Quién
# j: dice
# j: que
# j: no
# j: ?
# i: - Tú, grandísimo tonto.
# j: -
# j: Tú
# j: ,
# j: grandísimo
# j: tonto
# j: .
# i: Dijiste que teníamos toda la energía que necesitábamos, para siempre.
# j: Dijiste
# j: que
# j: teníamos
# j: toda
# j: la
# j: energía
# j: que
# j: necesitábamos
# j: ,
# j: para
# j: siempre
# j: .
# i: Dijiste &#39;para siempre&#39;.
# j: Dijiste
# j: &#39;para
# j: siempre
# j: &#39;
# j: .
# i: Esa vez le tocó a Adell oponerse.
# j: Esa
# j: vez
# j: le
# j: tocó
# j: a
# j: Adell
# j: oponerse
# j: .
# i: - Tal vez podamos reconstruir las cosas algún día.
# j: -
# j: Tal
# j: vez
# j: podamos
# j: reconstruir
# j: las
# j: cosas
# j: algún
# j: día
# j: .
# i: 4 - Nunca.
# j: 4
# j: -
# j: Nunca
# j: .
# i: - ¿Por qué no?
# j: -
# j: ¿Por
# j: qué
# j: no
# j: ?
# i: Algún día.
# j: Algún
# j: día
# j: .
# i: - Nunca.
# j: -
# j: Nunca
# j: .
# i: - Pregúntale a Multivac.
# j: -
# j: Pregúntale
# j: a
# j: Multivac
# j: .
# i: - Pregúntale tú a Multivac.
# j: -
# j: Pregúntale
# j: tú
# j: a
# j: Multivac
# j: .
# i: Te desafío.
# j: Te
# j: desafío
# j: .
# i: Te apuesto cinco dólares a que no es posible.
# j: Te
# j: apuesto
# j: cinco
# j: dólares
# j: a
# j: que
# j: no
# j: es
# j: posible
# j: .
# i: Adell estaba lo suficientemente borracho como para intentarlo y lo suficientemente sobrio como para traducir los símbolos y operaciones necesarias para formular la pregunta que, en palabras, podría haber correspondido a esto: ¿Podrá la humanidad algún día, sin el gasto neto de energía, devolver al Sol toda su juventud aún después que haya muerto de viejo?
# j: Adell
# j: estaba
# j: lo
# j: suficientemente
# j: borracho
# j: como
# j: para
# j: intentarlo
# j: y
# j: lo
# j: suficientemente
# j: sobrio
# j: como
# j: para
# j: traducir
# j: los
# j: símbolos
# j: y
# j: operaciones
# j: necesarias
# j: para
# j: formular
# j: la
# j: pregunta
# j: que
# j: ,
# j: en
# j: palabras
# j: ,
# j: podría
# j: haber
# j: correspondido
# j: a
# j: esto
# j: :
# j: ¿Podrá
# j: la
# j: humanidad
# j: algún
# j: día
# j: ,
# j: sin
# j: el
# j: gasto
# j: neto
# j: de
# j: energía
# j: ,
# j: devolver
# j: al
# j: Sol
# j: toda
# j: su
# j: juventud
# j: aún
# j: después
# j: que
# j: haya
# j: muerto
# j: de
# j: viejo
# j: ?
# i: O tal vez podría reducirse a una pregunta más simple, como ésta: ¿Cómo puede disminuirse masivamente la cantidad neta de entropía del universo?
# j: O
# j: tal
# j: vez
# j: podría
# j: reducirse
# j: a
# j: una
# j: pregunta
# j: más
# j: simple
# j: ,
# j: como
# j: ésta
# j: :
# j: ¿Cómo
# j: puede
# j: disminuirse
# j: masivamente
# j: la
# j: cantidad
# j: neta
# j: de
# j: entropía
# j: del
# j: universo
# j: ?
# i: Multivac enmudeció.
# j: Multivac
# j: enmudeció
# j: .
# i: Los lentos resplandores oscuros cesaron, los clicks distantes de los transmisores terminaron.
# j: Los
# j: lentos
# j: resplandores
# j: oscuros
# j: cesaron
# j: ,
# j: los
# j: clicks
# j: distantes
# j: de
# j: los
# j: transmisores
# j: terminaron
# j: .
# i: Entonces, mientras los asustados técnicos sentían que ya no podían contener más el aliento, el teletipo adjunto a la computadora cobró vida repentinamente.
# j: Entonces
# j: ,
# j: mientras
# j: los
# j: asustados
# j: técnicos
# j: sentían
# j: que
# j: ya
# j: no
# j: podían
# j: contener
# j: más
# j: el
# j: aliento
# j: ,
# j: el
# j: teletipo
# j: adjunto
# j: a
# j: la
# j: computadora
# j: cobró
# j: vida
# j: repentinamente
# j: .
# i: Aparecieron cinco palabras impresas: DATOS INSUFICIENTES PARA RESPUESTA ESCLARECEDORA.
# j: Aparecieron
# j: cinco
# j: palabras
# j: impresas
# j: :
# j: DATOS
# j: INSUFICIENTES
# j: PARA
# j: RESPUESTA
# j: ESCLARECEDORA
# j: .
# i: - No hay apuesta -murmuró Lupov.
# j: -
# j: No
# j: hay
# j: apuesta
# j: -murmuró
# j: Lupov
# j: .
# i: Salieron apresuradamente.
# j: Salieron
# j: apresuradamente
# j: .
# i: A la mañana siguiente, los dos, con dolor de cabeza y la boca pastosa, habían olvidado el incidente.
# j: A
# j: la
# j: mañana
# j: siguiente
# j: ,
# j: los
# j: dos
# j: ,
# j: con
# j: dolor
# j: de
# j: cabeza
# j: y
# j: la
# j: boca
# j: pastosa
# j: ,
# j: habían
# j: olvidado
# j: el
# j: incidente
# j: .
# i: Jerrodd, Jerrodine y Jerrodette I y II observaban la imagen estrellada en el visiplato mientras completaban el pasaje por el hiperespacio en un lapso fuera de las dimensiones del tiempo.
# j: Jerrodd
# j: ,
# j: Jerrodine
# j: y
# j: Jerrodette
# j: I
# j: y
# j: II
# j: observaban
# j: la
# j: imagen
# j: estrellada
# j: en
# j: el
# j: visiplato
# j: mientras
# j: completaban
# j: el
# j: pasaje
# j: por
# j: el
# j: hiperespacio
# j: en
# j: un
# j: lapso
# j: fuera
# j: de
# j: las
# j: dimensiones
# j: del
# j: tiempo
# j: .
# i: Inmediatamente, el uniforme de polvo de estrellas dio paso al predominio de un único disco de mármol, brillante, centrado.
# j: Inmediatamente
# j: ,
# j: el
# j: uniforme
# j: de
# j: polvo
# j: de
# j: estrellas
# j: dio
# j: paso
# j: al
# j: predominio
# j: de
# j: un
# j: único
# j: disco
# j: de
# j: mármol
# j: ,
# j: brillante
# j: ,
# j: centrado
# j: .
# i: - Es X-23 - dijo Jerrodd con confianza.
# j: -
# j: Es
# j: X-23
# j: -
# j: dijo
# j: Jerrodd
# j: con
# j: confianza
# j: .
# i: Sus manos delgadas se entrelazaron con fuerza detrás de su espalda y los nudillos se pusieron blancos.
# j: Sus
# j: manos
# j: delgadas
# j: se
# j: entrelazaron
# j: con
# j: fuerza
# j: detrás
# j: de
# j: su
# j: espalda
# j: y
# j: los
# j: nudillos
# j: se
# j: pusieron
# j: blancos
# j: .
# i: Las pequeñas Jerrodettes, niñas ambas, habían experimentado el pasaje por el hiperespacio por primera vez en su vida.
# j: Las
# j: pequeñas
# j: Jerrodettes
# j: ,
# j: niñas
# j: ambas
# j: ,
# j: habían
# j: experimentado
# j: el
# j: pasaje
# j: por
# j: el
# j: hiperespacio
# j: por
# j: primera
# j: vez
# j: en
# j: su
# j: vida
# j: .
# i: Contuvieron sus risas y se persiguieron locamente alrededor de la madre, gritando:  5 - Hemos llegado a X-23... hemos llegado a X-23... hemos llegado a X-23... hemos llegado... - Tranquilas, niñas -dijo rápidamente Jerrodine-.
# j: Contuvieron
# j: sus
# j: risas
# j: y
# j: se
# j: persiguieron
# j: locamente
# j: alrededor
# j: de
# j: la
# j: madre
# j: ,
# j: gritando
# j: :
# j: 5
# j: -
# j: Hemos
# j: llegado
# j: a
# j: X-23
# j: ...
# j: hemos
# j: llegado
# j: a
# j: X-23
# j: ...
# j: hemos
# j: llegado
# j: a
# j: X-23
# j: ...
# j: hemos
# j: llegado
# j: ...
# j: -
# j: Tranquilas
# j: ,
# j: niñas
# j: -dijo
# j: rápidamente
# j: Jerrodine-
# j: .
# i: ¿Estás seguro, Jerrodd?
# j: ¿Estás
# j: seguro
# j: ,
# j: Jerrodd
# j: ?
# i: - ¿De qué hay que estar seguro?
# j: -
# j: ¿De
# j: qué
# j: hay
# j: que
# j: estar
# j: seguro
# j: ?
# i: -preguntó Jerrodd, echando una mirada al tubo de metal justo debajo del techo, que ocupaba toda la longitud de la habitación y desaparecía a través de la pared en cada extremo.
# j: -preguntó
# j: Jerrodd
# j: ,
# j: echando
# j: una
# j: mirada
# j: al
# j: tubo
# j: de
# j: metal
# j: justo
# j: debajo
# j: del
# j: techo
# j: ,
# j: que
# j: ocupaba
# j: toda
# j: la
# j: longitud
# j: de
# j: la
# j: habitación
# j: y
# j: desaparecía
# j: a
# j: través
# j: de
# j: la
# j: pared
# j: en
# j: cada
# j: extremo
# j: .
# i: Tenía la misma longitud que la nave.
# j: Tenía
# j: la
# j: misma
# j: longitud
# j: que
# j: la
# j: nave
# j: .
# i: Jerrodd sabía poquísimo sobre el grueso tubo de metal excepto que se llamaba Microvac, que uno le hacía preguntas si lo deseaba; que aunque uno no se las hiciera de todas maneras cumplía con su tarea de conducir la nave hacia un destino prefijado, de abastecerla de energía desde alguna de las diversas estaciones de Energía Subgaláctica y de computar las ecuaciones para los saltos hiperespaciales.
# j: Jerrodd
# j: sabía
# j: poquísimo
# j: sobre
# j: el
# j: grueso
# j: tubo
# j: de
# j: metal
# j: excepto
# j: que
# j: se
# j: llamaba
# j: Microvac
# j: ,
# j: que
# j: uno
# j: le
# j: hacía
# j: preguntas
# j: si
# j: lo
# j: deseaba
# j: ;
# j: que
# j: aunque
# j: uno
# j: no
# j: se
# j: las
# j: hiciera
# j: de
# j: todas
# j: maneras
# j: cumplía
# j: con
# j: su
# j: tarea
# j: de
# j: conducir
# j: la
# j: nave
# j: hacia
# j: un
# j: destino
# j: prefijado
# j: ,
# j: de
# j: abastecerla
# j: de
# j: energía
# j: desde
# j: alguna
# j: de
# j: las
# j: diversas
# j: estaciones
# j: de
# j: Energía
# j: Subgaláctica
# j: y
# j: de
# j: computar
# j: las
# j: ecuaciones
# j: para
# j: los
# j: saltos
# j: hiperespaciales
# j: .
# i: Jerrodd y su familia no tenían otra cosa que hacer sino esperar y vivir en los cómodos sectores residenciales de la nave.
# j: Jerrodd
# j: y
# j: su
# j: familia
# j: no
# j: tenían
# j: otra
# j: cosa
# j: que
# j: hacer
# j: sino
# j: esperar
# j: y
# j: vivir
# j: en
# j: los
# j: cómodos
# j: sectores
# j: residenciales
# j: de
# j: la
# j: nave
# j: .
# i: Cierta vez alguien le había dicho a Jerrodd, que el &#39;ac&#39; al final de &#39;Microvac&#39; quería decir &#39;computadora análoga&#39; en inglés antiguo, pero estaba a punto de olvidar incluso eso.
# j: Cierta
# j: vez
# j: alguien
# j: le
# j: había
# j: dicho
# j: a
# j: Jerrodd
# j: ,
# j: que
# j: el
# j: &#39;ac
# j: &#39;
# j: al
# j: final
# j: de
# j: &#39;Microvac
# j: &#39;
# j: quería
# j: decir
# j: &#39;computadora
# j: análoga
# j: &#39;
# j: en
# j: inglés
# j: antiguo
# j: ,
# j: pero
# j: estaba
# j: a
# j: punto
# j: de
# j: olvidar
# j: incluso
# j: eso
# j: .
# i: Los ojos de Jerrodine estaban húmedos cuando miró el visiplato.
# j: Los
# j: ojos
# j: de
# j: Jerrodine
# j: estaban
# j: húmedos
# j: cuando
# j: miró
# j: el
# j: visiplato
# j: .
# i: - No puedo evitarlo.
# j: -
# j: No
# j: puedo
# j: evitarlo
# j: .
# i: Me siento extraña al salir de la Tierra.
# j: Me
# j: siento
# j: extraña
# j: al
# j: salir
# j: de
# j: la
# j: Tierra
# j: .
# i: - ¿Por qué, caramba?
# j: -
# j: ¿Por
# j: qué
# j: ,
# j: caramba
# j: ?
# i: -preguntó Jerrodd-.
# j: -preguntó
# j: Jerrodd-
# j: .
# i: No teníamos nada allí.
# j: No
# j: teníamos
# j: nada
# j: allí
# j: .
# i: En X-23 tendremos todo.
# j: En
# j: X-23
# j: tendremos
# j: todo
# j: .
# i: No estarás sola.
# j: No
# j: estarás
# j: sola
# j: .
# i: No serás una pionera.
# j: No
# j: serás
# j: una
# j: pionera
# j: .
# i: Ya hay un millón de personas en ese planeta.
# j: Ya
# j: hay
# j: un
# j: millón
# j: de
# j: personas
# j: en
# j: ese
# j: planeta
# j: .
# i: Por Dios, nuestros bisnietos tendrán que buscar nuevos mundos porque llegará el día en que X-23 estará superpoblado.
# j: Por
# j: Dios
# j: ,
# j: nuestros
# j: bisnietos
# j: tendrán
# j: que
# j: buscar
# j: nuevos
# j: mundos
# j: porque
# j: llegará
# j: el
# j: día
# j: en
# j: que
# j: X-23
# j: estará
# j: superpoblado
# j: .
# i: -Luego agregó, despues de una pausa reflexiva: - Te aseguro que es una suerte que las computadoras hayan desarrollado viajes interestelares, considerando el ritmo al que aumenta la raza.
# j: -Luego
# j: agregó
# j: ,
# j: despues
# j: de
# j: una
# j: pausa
# j: reflexiva
# j: :
# j: -
# j: Te
# j: aseguro
# j: que
# j: es
# j: una
# j: suerte
# j: que
# j: las
# j: computadoras
# j: hayan
# j: desarrollado
# j: viajes
# j: interestelares
# j: ,
# j: considerando
# j: el
# j: ritmo
# j: al
# j: que
# j: aumenta
# j: la
# j: raza
# j: .
# i: - Lo sé, lo sé -respondió Jerrodine con tristeza.
# j: -
# j: Lo
# j: sé
# j: ,
# j: lo
# j: sé
# j: -respondió
# j: Jerrodine
# j: con
# j: tristeza
# j: .
# i: Jerrodette I dijo de inmediato: - Nuestra Microvac es la mejor Microvac del mundo.
# j: Jerrodette
# j: I
# j: dijo
# j: de
# j: inmediato
# j: :
# j: -
# j: Nuestra
# j: Microvac
# j: es
# j: la
# j: mejor
# j: Microvac
# j: del
# j: mundo
# j: .
# i: - Eso creo yo también -repuso Jerrodd, desordenándole el pelo.
# j: -
# j: Eso
# j: creo
# j: yo
# j: también
# j: -repuso
# j: Jerrodd
# j: ,
# j: desordenándole
# j: el
# j: pelo
# j: .
# i: Era realmente una sensación muy agradable tener una Microvac propia y Jerrodd estaba contento de ser parte de su generación y no de otra.
# j: Era
# j: realmente
# j: una
# j: sensación
# j: muy
# j: agradable
# j: tener
# j: una
# j: Microvac
# j: propia
# j: y
# j: Jerrodd
# j: estaba
# j: contento
# j: de
# j: ser
# j: parte
# j: de
# j: su
# j: generación
# j: y
# j: no
# j: de
# j: otra
# j: .
# i: En la juventud de su  6 padre las únicas computadoras eran unas enormes máquinas que ocupaban un espacio de ciento cincuenta kilómetros cuadrados.
# j: En
# j: la
# j: juventud
# j: de
# j: su
# j: 6
# j: padre
# j: las
# j: únicas
# j: computadoras
# j: eran
# j: unas
# j: enormes
# j: máquinas
# j: que
# j: ocupaban
# j: un
# j: espacio
# j: de
# j: ciento
# j: cincuenta
# j: kilómetros
# j: cuadrados
# j: .
# i: Sólo había una por planeta.
# j: Sólo
# j: había
# j: una
# j: por
# j: planeta
# j: .
# i: Se llamaban ACs Planetarias.
# j: Se
# j: llamaban
# j: ACs
# j: Planetarias
# j: .
# i: Durante mil años habían crecido constantemente en tamaño y luego, de pronto, llegó el refinamiento.
# j: Durante
# j: mil
# j: años
# j: habían
# j: crecido
# j: constantemente
# j: en
# j: tamaño
# j: y
# j: luego
# j: ,
# j: de
# j: pronto
# j: ,
# j: llegó
# j: el
# j: refinamiento
# j: .
# i: En lugar de transistores hubo válvulas moleculares, de manera que hasta la AC Planetaria más grande podía colocarse en una nave espacial y ocupar sólo la mitad del espacio disponible.
# j: En
# j: lugar
# j: de
# j: transistores
# j: hubo
# j: válvulas
# j: moleculares
# j: ,
# j: de
# j: manera
# j: que
# j: hasta
# j: la
# j: AC
# j: Planetaria
# j: más
# j: grande
# j: podía
# j: colocarse
# j: en
# j: una
# j: nave
# j: espacial
# j: y
# j: ocupar
# j: sólo
# j: la
# j: mitad
# j: del
# j: espacio
# j: disponible
# j: .
# i: Jerrodd se sentía eufórico siempre que pensaba que su propia Microvac personal era muchísimo más compleja que la antigua y primitiva Multivac que por primera vez había domado al Sol, y casi tan complicada como una AC Planetaria de la Tierra (la más grande) que por primera vez resolvió el problema del viaje hiperespacial e hizo posibles los viajes a las estrellas.
# j: Jerrodd
# j: se
# j: sentía
# j: eufórico
# j: siempre
# j: que
# j: pensaba
# j: que
# j: su
# j: propia
# j: Microvac
# j: personal
# j: era
# j: muchísimo
# j: más
# j: compleja
# j: que
# j: la
# j: antigua
# j: y
# j: primitiva
# j: Multivac
# j: que
# j: por
# j: primera
# j: vez
# j: había
# j: domado
# j: al
# j: Sol
# j: ,
# j: y
# j: casi
# j: tan
# j: complicada
# j: como
# j: una
# j: AC
# j: Planetaria
# j: de
# j: la
# j: Tierra
# j: (
# j: la
# j: más
# j: grande
# j: )
# j: que
# j: por
# j: primera
# j: vez
# j: resolvió
# j: el
# j: problema
# j: del
# j: viaje
# j: hiperespacial
# j: e
# j: hizo
# j: posibles
# j: los
# j: viajes
# j: a
# j: las
# j: estrellas
# j: .
# i: - Tantas estrellas, tantos planetas -suspiró Jerrodine, inmersa en sus propios pensamientos-.
# j: -
# j: Tantas
# j: estrellas
# j: ,
# j: tantos
# j: planetas
# j: -suspiró
# j: Jerrodine
# j: ,
# j: inmersa
# j: en
# j: sus
# j: propios
# j: pensamientos-
# j: .
# i: Supongo que las familias seguirán emigrando siempre a nuevos planetas, tal como lo hacemos nosotros ahora.
# j: Supongo
# j: que
# j: las
# j: familias
# j: seguirán
# j: emigrando
# j: siempre
# j: a
# j: nuevos
# j: planetas
# j: ,
# j: tal
# j: como
# j: lo
# j: hacemos
# j: nosotros
# j: ahora
# j: .
# i: - No siempre -respondió Jerrodd, con una sonrisa-.
# j: -
# j: No
# j: siempre
# j: -respondió
# j: Jerrodd
# j: ,
# j: con
# j: una
# j: sonrisa-
# j: .
# i: Todo esto terminará algún día, pero no antes de que pasen billones de años.
# j: Todo
# j: esto
# j: terminará
# j: algún
# j: día
# j: ,
# j: pero
# j: no
# j: antes
# j: de
# j: que
# j: pasen
# j: billones
# j: de
# j: años
# j: .
# i: Muchos billones.
# j: Muchos
# j: billones
# j: .
# i: Hasta las estrellas se extinguen, ¿sabes?
# j: Hasta
# j: las
# j: estrellas
# j: se
# j: extinguen
# j: ,
# j: ¿sabes
# j: ?
# i: Tendrá que aumentar la entropía.
# j: Tendrá
# j: que
# j: aumentar
# j: la
# j: entropía
# j: .
# i: - ¿Qué es la entropía, papá?
# j: -
# j: ¿Qué
# j: es
# j: la
# j: entropía
# j: ,
# j: papá
# j: ?
# i: -preguntó Jerrodette II con voz aguda.
# j: -preguntó
# j: Jerrodette
# j: II
# j: con
# j: voz
# j: aguda
# j: .
# i: - Entropía, querida, es sólo una palabra que significa la cantidad de desgaste del universo.
# j: -
# j: Entropía
# j: ,
# j: querida
# j: ,
# j: es
# j: sólo
# j: una
# j: palabra
# j: que
# j: significa
# j: la
# j: cantidad
# j: de
# j: desgaste
# j: del
# j: universo
# j: .
# i: Todo se desgasta, como sabrás, por ejemplo tu pequeño robot walkietalkie, ¿recuerdas?
# j: Todo
# j: se
# j: desgasta
# j: ,
# j: como
# j: sabrás
# j: ,
# j: por
# j: ejemplo
# j: tu
# j: pequeño
# j: robot
# j: walkietalkie
# j: ,
# j: ¿recuerdas
# j: ?
# i: - ¿No puedes ponerle una nueva unidad de energía, como a mi robot?
# j: -
# j: ¿No
# j: puedes
# j: ponerle
# j: una
# j: nueva
# j: unidad
# j: de
# j: energía
# j: ,
# j: como
# j: a
# j: mi
# j: robot
# j: ?
# i: - Las estrellas son unidades de energía, querida.
# j: -
# j: Las
# j: estrellas
# j: son
# j: unidades
# j: de
# j: energía
# j: ,
# j: querida
# j: .
# i: Una vez que se extinguen, ya no hay más unidades de energía.
# j: Una
# j: vez
# j: que
# j: se
# j: extinguen
# j: ,
# j: ya
# j: no
# j: hay
# j: más
# j: unidades
# j: de
# j: energía
# j: .
# i: Jerrodette I lanzó un chillido de inmediato.
# j: Jerrodette
# j: I
# j: lanzó
# j: un
# j: chillido
# j: de
# j: inmediato
# j: .
# i: - No las dejes, papá.
# j: -
# j: No
# j: las
# j: dejes
# j: ,
# j: papá
# j: .
# i: No permitas que las estrellas se extingan.
# j: No
# j: permitas
# j: que
# j: las
# j: estrellas
# j: se
# j: extingan
# j: .
# i: - Mira lo que has hecho -susurró Jerrodine, exasperada.
# j: -
# j: Mira
# j: lo
# j: que
# j: has
# j: hecho
# j: -susurró
# j: Jerrodine
# j: ,
# j: exasperada
# j: .
# i: - ¿Cómo podía saber que iba a asustarla?
# j: -
# j: ¿Cómo
# j: podía
# j: saber
# j: que
# j: iba
# j: a
# j: asustarla
# j: ?
# i: -respondió Jerrodd también en un susurro.
# j: -respondió
# j: Jerrodd
# j: también
# j: en
# j: un
# j: susurro
# j: .
# i: - Pregúntale a la Microvac -gimió Jerrodette I-.
# j: -
# j: Pregúntale
# j: a
# j: la
# j: Microvac
# j: -gimió
# j: Jerrodette
# j: I-
# j: .
# i: Pregúntale cómo volver a encender las estrellas.
# j: Pregúntale
# j: cómo
# j: volver
# j: a
# j: encender
# j: las
# j: estrellas
# j: .
# i: - Vamos -dijo Jerrodine-.
# j: -
# j: Vamos
# j: -dijo
# j: Jerrodine-
# j: .
# i: Con eso se tranquilizarán.
# j: Con
# j: eso
# j: se
# j: tranquilizarán
# j: .
# i: -(Jerrodette II ya se estaba echando a llorar, también).
# j: -
# j: (
# j: Jerrodette
# j: II
# j: ya
# j: se
# j: estaba
# j: echando
# j: a
# j: llorar
# j: ,
# j: también
# j: )
# j: .
# i: Jerrodd se encogió de hombros.
# j: Jerrodd
# j: se
# j: encogió
# j: de
# j: hombros
# j: .
# i: 7 - Ya está bien, queridas.
# j: 7
# j: -
# j: Ya
# j: está
# j: bien
# j: ,
# j: queridas
# j: .
# i: Le preguntaré a Microvac.
# j: Le
# j: preguntaré
# j: a
# j: Microvac
# j: .
# i: No se preocupen, ella nos lo dirá.
# j: No
# j: se
# j: preocupen
# j: ,
# j: ella
# j: nos
# j: lo
# j: dirá
# j: .
# i: Le preguntó a la Microvac, y agregó rápidamente: - Imprimir la respuesta.
# j: Le
# j: preguntó
# j: a
# j: la
# j: Microvac
# j: ,
# j: y
# j: agregó
# j: rápidamente
# j: :
# j: -
# j: Imprimir
# j: la
# j: respuesta
# j: .
# i: Jerrodd retiró la delgada cinta de celufilm y dijo alegremente: - Miren, la Microvac dice que se ocupará de todo cuando llegue el momento, y que no se preocupen.
# j: Jerrodd
# j: retiró
# j: la
# j: delgada
# j: cinta
# j: de
# j: celufilm
# j: y
# j: dijo
# j: alegremente
# j: :
# j: -
# j: Miren
# j: ,
# j: la
# j: Microvac
# j: dice
# j: que
# j: se
# j: ocupará
# j: de
# j: todo
# j: cuando
# j: llegue
# j: el
# j: momento
# j: ,
# j: y
# j: que
# j: no
# j: se
# j: preocupen
# j: .
# i: Jerrodine dijo: - Y ahora, niñas, es hora de acostarse.
# j: Jerrodine
# j: dijo
# j: :
# j: -
# j: Y
# j: ahora
# j: ,
# j: niñas
# j: ,
# j: es
# j: hora
# j: de
# j: acostarse
# j: .
# i: Pronto estaremos en nuestro nuevo hogar.
# j: Pronto
# j: estaremos
# j: en
# j: nuestro
# j: nuevo
# j: hogar
# j: .
# i: Jerrodd leyó las palabras en el celufilm nuevamente antes de destruirlo: DATOS INSUFICIENTES PARA RESPUESTA ESCLARECEDORA.
# j: Jerrodd
# j: leyó
# j: las
# j: palabras
# j: en
# j: el
# j: celufilm
# j: nuevamente
# j: antes
# j: de
# j: destruirlo
# j: :
# j: DATOS
# j: INSUFICIENTES
# j: PARA
# j: RESPUESTA
# j: ESCLARECEDORA
# j: .
# i: Se encogió de hombros y miró el visiplato.
# j: Se
# j: encogió
# j: de
# j: hombros
# j: y
# j: miró
# j: el
# j: visiplato
# j: .
# i: El X-23 estaba cerca.
# j: El
# j: X-23
# j: estaba
# j: cerca
# j: .
# i: VJ-23X de Lameth miró las negras profundidades del mapa tridimensional en pequeña escala de la Galaxia y dijo: - ¿No será una ridiculez que nos preocupe tanto la cuestión?
# j: VJ-23X
# j: de
# j: Lameth
# j: miró
# j: las
# j: negras
# j: profundidades
# j: del
# j: mapa
# j: tridimensional
# j: en
# j: pequeña
# j: escala
# j: de
# j: la
# j: Galaxia
# j: y
# j: dijo
# j: :
# j: -
# j: ¿No
# j: será
# j: una
# j: ridiculez
# j: que
# j: nos
# j: preocupe
# j: tanto
# j: la
# j: cuestión
# j: ?
# i: MQ-17J de Nicron sacudió la cabeza.
# j: MQ-17J
# j: de
# j: Nicron
# j: sacudió
# j: la
# j: cabeza
# j: .
# i: - Creo que no.
# j: -
# j: Creo
# j: que
# j: no
# j: .
# i: Sabes que la Galaxia estará llena en cinco años con el actual ritmo de expansión.
# j: Sabes
# j: que
# j: la
# j: Galaxia
# j: estará
# j: llena
# j: en
# j: cinco
# j: años
# j: con
# j: el
# j: actual
# j: ritmo
# j: de
# j: expansión
# j: .
# i: Los dos parecían jóvenes de poco más de veinte años.
# j: Los
# j: dos
# j: parecían
# j: jóvenes
# j: de
# j: poco
# j: más
# j: de
# j: veinte
# j: años
# j: .
# i: Ambos eran altos y de formas perfectas.
# j: Ambos
# j: eran
# j: altos
# j: y
# j: de
# j: formas
# j: perfectas
# j: .
# i: - Sin embargo, dijo VJ-23X- me resisto a presentar un informe pesimista al Consejo Galáctico.
# j: -
# j: Sin
# j: embargo
# j: ,
# j: dijo
# j: VJ-23X-
# j: me
# j: resisto
# j: a
# j: presentar
# j: un
# j: informe
# j: pesimista
# j: al
# j: Consejo
# j: Galáctico
# j: .
# i: - Yo no pensaría en presentar ningún otro tipo de informe.
# j: -
# j: Yo
# j: no
# j: pensaría
# j: en
# j: presentar
# j: ningún
# j: otro
# j: tipo
# j: de
# j: informe
# j: .
# i: Tenemos que inquietarlos un poco.
# j: Tenemos
# j: que
# j: inquietarlos
# j: un
# j: poco
# j: .
# i: No hay otro remedio.
# j: No
# j: hay
# j: otro
# j: remedio
# j: .
# i: VJ-23X suspiró.
# j: VJ-23X
# j: suspiró
# j: .
# i: - El espacio es infinito.
# j: -
# j: El
# j: espacio
# j: es
# j: infinito
# j: .
# i: Hay cien billones de galaxias disponibles.
# j: Hay
# j: cien
# j: billones
# j: de
# j: galaxias
# j: disponibles
# j: .
# i: - Cien billones no es infinito, y cada vez se hace menos infinito.
# j: -
# j: Cien
# j: billones
# j: no
# j: es
# j: infinito
# j: ,
# j: y
# j: cada
# j: vez
# j: se
# j: hace
# j: menos
# j: infinito
# j: .
# i: ¡Piénsalo!
# j: ¡Piénsalo
# j: !
# i: Hace veinte mil años, la humanidad resolvió por primera vez el problema de utilizar energía estelar, y algunos siglos después se hicieron posibles los viajes  8 interestelares.
# j: Hace
# j: veinte
# j: mil
# j: años
# j: ,
# j: la
# j: humanidad
# j: resolvió
# j: por
# j: primera
# j: vez
# j: el
# j: problema
# j: de
# j: utilizar
# j: energía
# j: estelar
# j: ,
# j: y
# j: algunos
# j: siglos
# j: después
# j: se
# j: hicieron
# j: posibles
# j: los
# j: viajes
# j: 8
# j: interestelares
# j: .
# i: A la humanidad le llevó un millón de años llenar un pequeño mundo y luego sólo quince mil años llenar el resto de la Galaxia.
# j: A
# j: la
# j: humanidad
# j: le
# j: llevó
# j: un
# j: millón
# j: de
# j: años
# j: llenar
# j: un
# j: pequeño
# j: mundo
# j: y
# j: luego
# j: sólo
# j: quince
# j: mil
# j: años
# j: llenar
# j: el
# j: resto
# j: de
# j: la
# j: Galaxia
# j: .
# i: Ahora la población se duplica cada diez años... VJ-23X lo interrumpió.
# j: Ahora
# j: la
# j: población
# j: se
# j: duplica
# j: cada
# j: diez
# j: años
# j: ...
# j: VJ-23X
# j: lo
# j: interrumpió
# j: .
# i: - Eso debemos agradecérselo a la inmnortalidad.
# j: -
# j: Eso
# j: debemos
# j: agradecérselo
# j: a
# j: la
# j: inmnortalidad
# j: .
# i: - Muy bien.
# j: -
# j: Muy
# j: bien
# j: .
# i: La inmortalidad existe y debemos considerarla.
# j: La
# j: inmortalidad
# j: existe
# j: y
# j: debemos
# j: considerarla
# j: .
# i: Admito que esta inmortalidad tiene su lado complicado.
# j: Admito
# j: que
# j: esta
# j: inmortalidad
# j: tiene
# j: su
# j: lado
# j: complicado
# j: .
# i: La galáctica AC nos ha solucionado muchos problemas, pero al resolver el problema de evitar la vejez y la muerte, anuló todas las otras cuestiones.
# j: La
# j: galáctica
# j: AC
# j: nos
# j: ha
# j: solucionado
# j: muchos
# j: problemas
# j: ,
# j: pero
# j: al
# j: resolver
# j: el
# j: problema
# j: de
# j: evitar
# j: la
# j: vejez
# j: y
# j: la
# j: muerte
# j: ,
# j: anuló
# j: todas
# j: las
# j: otras
# j: cuestiones
# j: .
# i: - Sin embargo no creo que desees abandonar la vida.
# j: -
# j: Sin
# j: embargo
# j: no
# j: creo
# j: que
# j: desees
# j: abandonar
# j: la
# j: vida
# j: .
# i: - En absoluto -saltó MQ-17J, y luego se suavizó de inmediato-.
# j: -
# j: En
# j: absoluto
# j: -saltó
# j: MQ-17J
# j: ,
# j: y
# j: luego
# j: se
# j: suavizó
# j: de
# j: inmediato-
# j: .
# i: No todavía.
# j: No
# j: todavía
# j: .
# i: No soy tan viejo.
# j: No
# j: soy
# j: tan
# j: viejo
# j: .
# i: ¿Cuántos años tienes tú?
# j: ¿Cuántos
# j: años
# j: tienes
# j: tú
# j: ?
# i: - Doscientos veintitrés.
# j: -
# j: Doscientos
# j: veintitrés
# j: .
# i: ¿Y tú?
# j: ¿Y
# j: tú
# j: ?
# i: - Yo todavía no tengo doscientos.
# j: -
# j: Yo
# j: todavía
# j: no
# j: tengo
# j: doscientos
# j: .
# i: Pero, volvamos a lo que decía.
# j: Pero
# j: ,
# j: volvamos
# j: a
# j: lo
# j: que
# j: decía
# j: .
# i: La población se duplica cada diez años.
# j: La
# j: población
# j: se
# j: duplica
# j: cada
# j: diez
# j: años
# j: .
# i: Una vez que se llene esta galaxia, habremos llenado otra en diez años.
# j: Una
# j: vez
# j: que
# j: se
# j: llene
# j: esta
# j: galaxia
# j: ,
# j: habremos
# j: llenado
# j: otra
# j: en
# j: diez
# j: años
# j: .
# i: Diez años más y habremos llenado dos más.
# j: Diez
# j: años
# j: más
# j: y
# j: habremos
# j: llenado
# j: dos
# j: más
# j: .
# i: Otra década, cuatro más.
# j: Otra
# j: década
# j: ,
# j: cuatro
# j: más
# j: .
# i: En cien años, habremos llenado mil galaxias; en mil años, un millón de galaxias.
# j: En
# j: cien
# j: años
# j: ,
# j: habremos
# j: llenado
# j: mil
# j: galaxias
# j: ;
# j: en
# j: mil
# j: años
# j: ,
# j: un
# j: millón
# j: de
# j: galaxias
# j: .
# i: En diez mil años, todo el universo conocido.
# j: En
# j: diez
# j: mil
# j: años
# j: ,
# j: todo
# j: el
# j: universo
# j: conocido
# j: .
# i: Y entonces, ¿qué?
# j: Y
# j: entonces
# j: ,
# j: ¿qué
# j: ?
# i: VJ-23X dijo: - Como problema paralelo, está el del transporte.
# j: VJ-23X
# j: dijo
# j: :
# j: -
# j: Como
# j: problema
# j: paralelo
# j: ,
# j: está
# j: el
# j: del
# j: transporte
# j: .
# i: Me pregunto cuántas unidades de energía solar se necesitarán para trasladar galaxias de individuos de una galaxia a la siguiente.
# j: Me
# j: pregunto
# j: cuántas
# j: unidades
# j: de
# j: energía
# j: solar
# j: se
# j: necesitarán
# j: para
# j: trasladar
# j: galaxias
# j: de
# j: individuos
# j: de
# j: una
# j: galaxia
# j: a
# j: la
# j: siguiente
# j: .
# i: - Muy buena observación.
# j: -
# j: Muy
# j: buena
# j: observación
# j: .
# i: La humanidad ya consume dos unidades de energía solar por año.
# j: La
# j: humanidad
# j: ya
# j: consume
# j: dos
# j: unidades
# j: de
# j: energía
# j: solar
# j: por
# j: año
# j: .
# i: - La mayor parte de esta energía se desperdicia.
# j: -
# j: La
# j: mayor
# j: parte
# j: de
# j: esta
# j: energía
# j: se
# j: desperdicia
# j: .
# i: Al fin y al cabo, nuestra propia galaxia sola gasta mil unidades de energía solar por año, y nosotros solamente usamos dos de ellas.
# j: Al
# j: fin
# j: y
# j: al
# j: cabo
# j: ,
# j: nuestra
# j: propia
# j: galaxia
# j: sola
# j: gasta
# j: mil
# j: unidades
# j: de
# j: energía
# j: solar
# j: por
# j: año
# j: ,
# j: y
# j: nosotros
# j: solamente
# j: usamos
# j: dos
# j: de
# j: ellas
# j: .
# i: - De acuerdo, pero aún con una eficiencia de un cien por ciento, sólo podemos postergar el final.
# j: -
# j: De
# j: acuerdo
# j: ,
# j: pero
# j: aún
# j: con
# j: una
# j: eficiencia
# j: de
# j: un
# j: cien
# j: por
# j: ciento
# j: ,
# j: sólo
# j: podemos
# j: postergar
# j: el
# j: final
# j: .
# i: Nuestras necesidades energéticas crecen en progresión geométrica, y a un ritmo mayor que nuestra población.
# j: Nuestras
# j: necesidades
# j: energéticas
# j: crecen
# j: en
# j: progresión
# j: geométrica
# j: ,
# j: y
# j: a
# j: un
# j: ritmo
# j: mayor
# j: que
# j: nuestra
# j: población
# j: .
# i: Nos quedaremos sin energía todavía más rápido que sin galaxias.
# j: Nos
# j: quedaremos
# j: sin
# j: energía
# j: todavía
# j: más
# j: rápido
# j: que
# j: sin
# j: galaxias
# j: .
# i: Muy buena observación.
# j: Muy
# j: buena
# j: observación
# j: .
# i: Muy, muy buena observación.
# j: Muy
# j: ,
# j: muy
# j: buena
# j: observación
# j: .
# i: - Simplemente tendremos que construir nuevas estrellas con gas interestelar.
# j: -
# j: Simplemente
# j: tendremos
# j: que
# j: construir
# j: nuevas
# j: estrellas
# j: con
# j: gas
# j: interestelar
# j: .
# i: 9 - ¿O con calor disipado?
# j: 9
# j: -
# j: ¿O
# j: con
# j: calor
# j: disipado
# j: ?
# i: -preguntó MQ-17J, con tono sarcástico.
# j: -preguntó
# j: MQ-17J
# j: ,
# j: con
# j: tono
# j: sarcástico
# j: .
# i: - Puede haber alguna forma de revertir la entropía.
# j: -
# j: Puede
# j: haber
# j: alguna
# j: forma
# j: de
# j: revertir
# j: la
# j: entropía
# j: .
# i: Tenemos que preguntárselo a la Galáctica AC.
# j: Tenemos
# j: que
# j: preguntárselo
# j: a
# j: la
# j: Galáctica
# j: AC
# j: .
# i: VJ-23X no hablaba realmente en serio, pero MQ-17J sacó su contacto AC del bolsillo y lo colocó sobre la mesa frente a él.
# j: VJ-23X
# j: no
# j: hablaba
# j: realmente
# j: en
# j: serio
# j: ,
# j: pero
# j: MQ-17J
# j: sacó
# j: su
# j: contacto
# j: AC
# j: del
# j: bolsillo
# j: y
# j: lo
# j: colocó
# j: sobre
# j: la
# j: mesa
# j: frente
# j: a
# j: él
# j: .
# i: - No me faltan ganas -dijo-.
# j: -
# j: No
# j: me
# j: faltan
# j: ganas
# j: -dijo-
# j: .
# i: Es algo que la raza humana tendrá que enfrentar algún día.
# j: Es
# j: algo
# j: que
# j: la
# j: raza
# j: humana
# j: tendrá
# j: que
# j: enfrentar
# j: algún
# j: día
# j: .
# i: Miró sombríamente su pequeño contacto AC.
# j: Miró
# j: sombríamente
# j: su
# j: pequeño
# j: contacto
# j: AC
# j: .
# i: Era un objeto de apenas cinco centímetros cúbicos, nada en sí mismo, pero estaba conectado a través del hiperespacio con la gran Galáctica AC que servía a toda la humanidad y, a su vez era parte integral suya.
# j: Era
# j: un
# j: objeto
# j: de
# j: apenas
# j: cinco
# j: centímetros
# j: cúbicos
# j: ,
# j: nada
# j: en
# j: sí
# j: mismo
# j: ,
# j: pero
# j: estaba
# j: conectado
# j: a
# j: través
# j: del
# j: hiperespacio
# j: con
# j: la
# j: gran
# j: Galáctica
# j: AC
# j: que
# j: servía
# j: a
# j: toda
# j: la
# j: humanidad
# j: y
# j: ,
# j: a
# j: su
# j: vez
# j: era
# j: parte
# j: integral
# j: suya
# j: .
# i: MQ-17J hizo una pausa para preguntarse si algún día, en su vida inmortal, llegaría a ver la Galáctica AC.
# j: MQ-17J
# j: hizo
# j: una
# j: pausa
# j: para
# j: preguntarse
# j: si
# j: algún
# j: día
# j: ,
# j: en
# j: su
# j: vida
# j: inmortal
# j: ,
# j: llegaría
# j: a
# j: ver
# j: la
# j: Galáctica
# j: AC
# j: .
# i: Era un pequeño mundo propio, una telaraña de rayos de energía que contenía la materia dentro de la cual las oleadas de los planos medios ocupaban el lugar de las antiguas y pesadas válvulas moleculares.
# j: Era
# j: un
# j: pequeño
# j: mundo
# j: propio
# j: ,
# j: una
# j: telaraña
# j: de
# j: rayos
# j: de
# j: energía
# j: que
# j: contenía
# j: la
# j: materia
# j: dentro
# j: de
# j: la
# j: cual
# j: las
# j: oleadas
# j: de
# j: los
# j: planos
# j: medios
# j: ocupaban
# j: el
# j: lugar
# j: de
# j: las
# j: antiguas
# j: y
# j: pesadas
# j: válvulas
# j: moleculares
# j: .
# i: Sin embargo, a pesar de esos funcionamientos subetéreos, se sabía que la Galáctica AC tenía mil diez metros de ancho.
# j: Sin
# j: embargo
# j: ,
# j: a
# j: pesar
# j: de
# j: esos
# j: funcionamientos
# j: subetéreos
# j: ,
# j: se
# j: sabía
# j: que
# j: la
# j: Galáctica
# j: AC
# j: tenía
# j: mil
# j: diez
# j: metros
# j: de
# j: ancho
# j: .
# i: Repentinamente, MQ-17J preguntó a su contacto AC: - ¿Es posible revertir la entropía?
# j: Repentinamente
# j: ,
# j: MQ-17J
# j: preguntó
# j: a
# j: su
# j: contacto
# j: AC
# j: :
# j: -
# j: ¿Es
# j: posible
# j: revertir
# j: la
# j: entropía
# j: ?
# i: VJ-23X, sobresaltado, dijo de inmediato: - Ah, mira, realmente yo no quise decir que tenías que preguntar eso.
# j: VJ-23X
# j: ,
# j: sobresaltado
# j: ,
# j: dijo
# j: de
# j: inmediato
# j: :
# j: -
# j: Ah
# j: ,
# j: mira
# j: ,
# j: realmente
# j: yo
# j: no
# j: quise
# j: decir
# j: que
# j: tenías
# j: que
# j: preguntar
# j: eso
# j: .
# i: - ¿Por qué no?
# j: -
# j: ¿Por
# j: qué
# j: no
# j: ?
# i: - Los dos sabemos que la entropía no puede revertirse.
# j: -
# j: Los
# j: dos
# j: sabemos
# j: que
# j: la
# j: entropía
# j: no
# j: puede
# j: revertirse
# j: .
# i: No puedes volver a convertir el humo y las cenizas en un árbol.
# j: No
# j: puedes
# j: volver
# j: a
# j: convertir
# j: el
# j: humo
# j: y
# j: las
# j: cenizas
# j: en
# j: un
# j: árbol
# j: .
# i: - ¿Hay árboles en tu mundo?
# j: -
# j: ¿Hay
# j: árboles
# j: en
# j: tu
# j: mundo
# j: ?
# i: -preguntó MQ-17J.
# j: -preguntó
# j: MQ-17J
# j: .
# i: El sonido de la Galáctica AC los sobresaltó y les hizo guardar silencio.
# j: El
# j: sonido
# j: de
# j: la
# j: Galáctica
# j: AC
# j: los
# j: sobresaltó
# j: y
# j: les
# j: hizo
# j: guardar
# j: silencio
# j: .
# i: Se oyó su voz fina y hermosa en el contacto AC en el escritorio.
# j: Se
# j: oyó
# j: su
# j: voz
# j: fina
# j: y
# j: hermosa
# j: en
# j: el
# j: contacto
# j: AC
# j: en
# j: el
# j: escritorio
# j: .
# i: Dijo: DATOS INSUFICIENTES PARA RESPUESTA ESCLARECEDORA.
# j: Dijo
# j: :
# j: DATOS
# j: INSUFICIENTES
# j: PARA
# j: RESPUESTA
# j: ESCLARECEDORA
# j: .
# i: VJ-23X dijo: - ¡Ves!
# j: VJ-23X
# j: dijo
# j: :
# j: -
# j: ¡Ves
# j: !
# i: 10 Entonces los dos hombres volvieron a la pregunta del informe que tenían que hacer para el Consejo Galáctico.
# j: 10
# j: Entonces
# j: los
# j: dos
# j: hombres
# j: volvieron
# j: a
# j: la
# j: pregunta
# j: del
# j: informe
# j: que
# j: tenían
# j: que
# j: hacer
# j: para
# j: el
# j: Consejo
# j: Galáctico
# j: .
# i: La mente de Zee Prime abarcó la nueva galaxia con un leve interés en los incontables racimos de estrellas que la poblaban.
# j: La
# j: mente
# j: de
# j: Zee
# j: Prime
# j: abarcó
# j: la
# j: nueva
# j: galaxia
# j: con
# j: un
# j: leve
# j: interés
# j: en
# j: los
# j: incontables
# j: racimos
# j: de
# j: estrellas
# j: que
# j: la
# j: poblaban
# j: .
# i: Nunca había visto eso antes.
# j: Nunca
# j: había
# j: visto
# j: eso
# j: antes
# j: .
# i: ¿Alguna vez las vería todas?
# j: ¿Alguna
# j: vez
# j: las
# j: vería
# j: todas
# j: ?
# i: Tantas estrellas, cada una con su carga de humanidad... una carga que era casi un peso muerto.
# j: Tantas
# j: estrellas
# j: ,
# j: cada
# j: una
# j: con
# j: su
# j: carga
# j: de
# j: humanidad
# j: ...
# j: una
# j: carga
# j: que
# j: era
# j: casi
# j: un
# j: peso
# j: muerto
# j: .
# i: Cada vez más, la verdadera esencia del hombre había que encontrarla allá afuera, en el espacio.
# j: Cada
# j: vez
# j: más
# j: ,
# j: la
# j: verdadera
# ...
# j: .
# i: Su mente dejó de centrarse en la Galaxia original del hombre, y le permitió volver y perderse en pequeños puntos nebulosos.
# j: Su
# j: mente
# j: dejó
# j: de
# j: centrarse
# j: en
# j: la
# j: Galaxia
# j: original
# j: del
# j: hombre
# j: ,
# j: y
# j: le
# j: permitió
# j: volver
# j: y
# j: perderse
# j: en
# j: pequeños
# j: puntos
# j: nebulosos
# j: .
# i: No quería volver a verla.
# j: No
# j: quería
# j: volver
# j: a
# j: verla
# j: .
# i: Dee Sub Wun dijo: - ¿Qué sucede?
# j: Dee
# j: Sub
# j: Wun
# j: dijo
# j: :
# j: -
# j: ¿Qué
# j: sucede
# j: ?
# i: - Las estrellas están muriendo.
# j: -
# j: Las
# j: estrellas
# j: están
# j: muriendo
# j: .
# i: La estrella original ha muerto.
# j: La
# j: estrella
# j: original
# j: ha
# j: muerto
# j: .
# i: - Todas deben morir.
# j: -
# j: Todas
# j: deben
# j: morir
# j: .
# i: ¿Por qué no?
# j: ¿Por
# j: qué
# j: no
# j: ?
# i: - Pero cuando toda la energía se haya agotado, nuestros cuerpos finalmente morirán, y tú y yo con ellos.
# j: -
# j: Pero
# j: cuando
# j: toda
# j: la
# j: energía
# j: se
# j: haya
# j: agotado
# j: ,
# j: nuestros
# j: cuerpos
# j: finalmente
# j: morirán
# j: ,
# j: y
# j: tú
# j: y
# j: yo
# j: con
# j: ellos
# j: .
# i: - Llevará billones de años.
# j: -
# j: Llevará
# j: billones
# j: de
# j: años
# j: .
# i: - No quiero que suceda, ni siquiera dentro de billones de años.
# j: -
# j: No
# j: quiero
# j: que
# j: suceda
# j: ,
# j: ni
# j: siquiera
# j: dentro
# j: de
# j: billones
# j: de
# j: años
# j: .
# i: ¡Universal AC!
# j: ¡Universal
# j: AC
# j: !
# i: ¿Cómo puede evitarse que las estrellas mueran?
# j: ¿Cómo
# j: puede
# j: evitarse
# j: que
# j: las
# j: estrellas
# j: mueran
# j: ?
# i: Dee Sub Wun dijo, divertido: - Estás preguntando cómo podría revertirse la dirección de la entropía.
# j: Dee
# j: Sub
# j: Wun
# j: dijo
# j: ,
# j: divertido
# j: :
# j: -
# j: Estás
# j: preguntando
# j: cómo
# j: podría
# j: revertirse
# j: la
# j: dirección
# j: de
# j: la
# j: entropía
# j: .
# i: Y la Universal AC respondió: TODAVÍA HAY DATOS INSUFICIENTES PARA UNA RESPUESTA ESCLARECEDORA.
# j: Y
# j: la
# j: Universal
# j: AC
# j: respondió
# j: :
# j: TODAVÍA
# j: HAY
# j: DATOS
# j: INSUFICIENTES
# j: PARA
# j: UNA
# j: RESPUESTA
# j: ESCLARECEDORA
# j: .
# i: Los pensamientos de Zee Prime volaron a su propia galaxia.
# j: Los
# j: pensamientos
# j: de
# j: Zee
# j: Prime
# j: volaron
# j: a
# j: su
# j: propia
# j: galaxia
# j: .
# i: Dejó de pensar en Dee Sub Wun, cuyo cuerpo podría estar esperando en una galaxia a un trillón de años luz de distancia, o en la estrella siguiente a la de Zee Prime.
# j: Dejó
# j: de
# j: pensar
# j: en
# j: Dee
# j: Sub
# j: Wun
# j: ,
# j: cuyo
# j: cuerpo
# j: podría
# j: estar
# j: esperando
# j: en
# j: una
# j: galaxia
# j: a
# j: un
# j: trillón
# j: de
# j: años
# j: luz
# j: de
# j: distancia
# j: ,
# j: o
# j: en
# j: la
# j: estrella
# j: siguiente
# j: a
# j: la
# j: de
# j: Zee
# j: Prime
# j: .
# i: No importaba.
# j: No
# j: importaba
# j: .
# i: 13 Con aire desdichado, Zee Prime comenzó a recoger hidrógeno interestelar con el cual construir una pequeña estrella propia.
# j: 13
# j: Con
# j: aire
# j: desdichado
# j: ,
# j: Zee
# j: Prime
# j: comenzó
# j: a
# j: recoger
# j: hidrógeno
# j: interestelar
# j: con
# j: el
# j: cual
# j: construir
# j: una
# j: pequeña
# j: estrella
# j: propia
# j: .
# i: Si las estrellas debían morir alguna vez, al menos podrían construirse algunas.
# j: Si
# j: las
# j: estrellas
# j: debían
# j: morir
# j: alguna
# j: vez
# j: ,
# j: al
# j: menos
# j: podrían
# j: construirse
# j: algunas
# j: .
# i: El Hombre, mentalmente, era uno solo, y estaba conformado por un trillón de trillones de cuerpos sin edad, cada uno en su lugar, cada uno descansando, tranquilo e incorruptible, cada uno cuidado por autómatas perfectos, igualmente incorruptibles, mientras las mentes de todos los cuerpos se fusionaban libremente entre sí, sin distinción.
# j: El
# j: Hombre
# j: ,
# j: mentalmente
# j: ,
# j: era
# j: uno
# j: solo
# j: ,
# j: y
# j: estaba
# j: conformado
# j: por
# j: un
# j: trillón
# j: de
# j: trillones
# j: de
# j: cuerpos
# j: sin
# j: edad
# j: ,
# j: cada
# j: uno
# j: en
# j: su
# j: lugar
# j: ,
# j: cada
# j: uno
# j: descansando
# j: ,
# j: tranquilo
# j: e
# j: incorruptible
# j: ,
# j: cada
# j: uno
# j: cuidado
# j: por
# j: autómatas
# j: perfectos
# j: ,
# j: igualmente
# j: incorruptibles
# j: ,
# j: mientras
# j: las
# j: mentes
# j: de
# j: todos
# j: los
# j: cuerpos
# j: se
# j: fusionaban
# j: libremente
# j: entre
# j: sí
# j: ,
# j: sin
# j: distinción
# j: .
# i: El Hombre dijo: - El universo está muriendo.
# j: El
# j: Hombre
# j: dijo
# j: :
# j: -
# j: El
# j: universo
# j: está
# j: muriendo
# j: .
# i: El Hombre miró a su alrededor a las galaxias cada vez más oscuras.
# j: El
# j: Hombre
# j: miró
# j: a
# j: su
# j: alrededor
# j: a
# j: las
# j: galaxias
# j: cada
# j: vez
# j: más
# j: oscuras
# j: .
# i: Las estrellas gigantes, muy gastadoras, se habían ido hace rato, habían vuelto a lo más oscuro de la oscuridad del pasado distante.
# j: Las
# j: estrellas
# j: gigantes
# j: ,
# j: muy
# j: gastadoras
# j: ,
# j: se
# j: habían
# j: ido
# j: hace
# j: rato
# j: ,
# j: habían
# j: vuelto
# j: a
# j: lo
# j: más
# j: oscuro
# j: de
# j: la
# j: oscuridad
# j: del
# j: pasado
# j: distante
# j: .
# i: Casi todas las estrellas eran enanas blancas, que finalmente se desvanecían.
# j: Casi
# j: todas
# j: las
# j: estrellas
# j: eran
# j: enanas
# j: blancas
# j: ,
# j: que
# j: finalmente
# j: se
# j: desvanecían
# j: .
# i: Se habían creado nuevas estrellas con el polvo que había entre ellas, algunas por procesos naturales, otras por el Hombre mismo, y también se estaban apagando.
# j: Se
# j: habían
# j: creado
# j: nuevas
# j: estrellas
# j: con
# j: el
# j: polvo
# j: que
# j: había
# j: entre
# j: ellas
# j: ,
# j: algunas
# j: por
# j: procesos
# j: naturales
# j: ,
# j: otras
# j: por
# j: el
# j: Hombre
# j: mismo
# j: ,
# j: y
# j: también
# j: se
# j: estaban
# j: apagando
# j: .
# i: Las enanas blancas aún podían chocar entre ellas, y de las poderosas fuerzas así liberadas se construirían nuevas estrellas, pero una sola estrella por cada mil estrellas enanas blancas destruidas, y también éstas llegarían a su fin.
# j: Las
# j: enanas
# j: blancas
# j: aún
# j: podían
# j: chocar
# j: entre
# j: ellas
# j: ,
# j: y
# j: de
# j: las
# j: poderosas
# j: fuerzas
# j: así
# j: liberadas
# j: se
# j: construirían
# j: nuevas
# j: estrellas
# j: ,
# j: pero
# j: una
# j: sola
# j: estrella
# j: por
# j: cada
# j: mil
# j: estrellas
# j: enanas
# j: blancas
# j: destruidas
# j: ,
# j: y
# j: también
# j: éstas
# j: llegarían
# j: a
# j: su
# j: fin
# j: .
# i: El Hombre dijo: - Cuidadosamente administrada y bajo la dirección de la Cósmica AC, la energía que todavía queda en todo el universo, puede durar billones de años.
# j: El
# j: Hombre
# j: dijo
# j: :
# j: -
# j: Cuidadosamente
# j: administrada
# j: y
# j: bajo
# j: la
# j: dirección
# j: de
# j: la
# j: Cósmica
# j: AC
# j: ,
# j: la
# j: energía
# j: que
# j: todavía
# j: queda
# j: en
# j: todo
# j: el
# j: universo
# j: ,
# j: puede
# j: durar
# j: billones
# j: de
# j: años
# j: .
# i: Pero aún así eventualmente todo llegará a su fin.
# j: Pero
# j: aún
# j: así
# j: eventualmente
# j: todo
# j: llegará
# j: a
# j: su
# j: fin
# j: .
# i: Por mejor que se la administre, por más que se la racione, la energía gastada desaparece y no puede ser repuesta.
# j: Por
# j: mejor
# j: que
# j: se
# j: la
# j: administre
# j: ,
# j: por
# j: más
# j: que
# j: se
# j: la
# j: racione
# j: ,
# j: la
# j: energía
# j: gastada
# j: desaparece
# j: y
# j: no
# j: puede
# j: ser
# j: repuesta
# j: .
# i: La entropía aumenta continuamente.
# j: La
# j: entropía
# j: aumenta
# j: continuamente
# j: .
# i: El Hombre dijo: - ¿Es posible no revertir la entropía?
# j: El
# j: Hombre
# j: dijo
# j: :
# j: -
# j: ¿Es
# j: posible
# j: no
# j: revertir
# j: la
# j: entropía
# j: ?
# i: Preguntémosle a la Cósmica AC.
# j: Preguntémosle
# j: a
# j: la
# j: Cósmica
# j: AC
# j: .
# i: La AC los rodeó pero no en el espacio.
# j: La
# j: AC
# j: los
# j: rodeó
# j: pero
# j: no
# j: en
# j: el
# j: espacio
# j: .
# i: Ni un solo fragmento de ella estaba en el espacio.
# j: Ni
# j: un
# j: solo
# j: fragmento
# j: de
# j: ella
# j: estaba
# j: en
# j: el
# j: espacio
# j: .
# i: Estaba en el hiperespacio y hecha de algo que no era materia ni energía.
# j: Estaba
# j: en
# j: el
# j: hiperespacio
# j: y
# j: hecha
# j: de
# j: algo
# j: que
# j: no
# j: era
# j: materia
# j: ni
# j: energía
# j: .
# i: La pregunta sobre su tamaño y su naturaleza ya no tenía sentido comprensible para el Hombre.
# j: La
# j: pregunta
# j: sobre
# j: su
# j: tamaño
# j: y
# j: su
# j: naturaleza
# j: ya
# j: no
# j: tenía
# j: sentido
# j: comprensible
# j: para
# j: el
# j: Hombre
# j: .
# i: - Cósmica AC -dijo el Hombre- ¿cómo puede revertirse la entropía?
# j: -
# j: Cósmica
# j: AC
# j: -dijo
# j: el
# j: Hombre-
# j: ¿cómo
# j: puede
# j: revertirse
# j: la
# j: entropía
# j: ?
# i: La Cósmica AC dijo:  14 LOS DATOS SON TODAVÍA INSUFICIENTES PARA UNA RESPUESTA ESCLARECEDORA.
# j: La
# j: Cósmica
# j: AC
# j: dijo
# j: :
# j: 14
# j: LOS
# j: DATOS
# j: SON
# j: TODAVÍA
# j: INSUFICIENTES
# j: PARA
# j: UNA
# j: RESPUESTA
# j: ESCLARECEDORA
# j: .
# i: El Hombre ordenó: - Recoge datos adicionales.
# j: El
# j: Hombre
# j: ordenó
# j: :
# j: -
# j: Recoge
# j: datos
# j: adicionales
# j: .
# i: La Cósmica AC dijo: LO HARÉ.
# j: La
# j: Cósmica
# j: AC
# j: dijo
# j: :
# j: LO
# j: HARÉ
# j: .
# i: HACE CIENTOS DE BILLONES DE AÑOS QUE LO HAGO.
# j: HACE
# j: CIENTOS
# j: DE
# j: BILLONES
# j: DE
# j: AÑOS
# j: QUE
# j: LO
# j: HAGO
# j: .
# i: MIS PREDECESORES Y YO HEMOS ESCUCHADO MUCHAS VECES ESTA PREGUNTA.
# j: MIS
# j: PREDECESORES
# j: Y
# j: YO
# j: HEMOS
# j: ESCUCHADO
# j: MUCHAS
# j: VECES
# j: ESTA
# j: PREGUNTA
# j: .
# i: TODOS LOS DATOS QUE TENGO SIGUEN SIENDO INSUFICIENTES.
# j: TODOS
# j: LOS
# j: DATOS
# j: QUE
# j: TENGO
# j: SIGUEN
# j: SIENDO
# j: INSUFICIENTES
# j: .
# i: - ¿Llegará el momento -preguntó el Hombre- en que los datos sean suficientes o el problema es insoluble en todas las circunstancias concebibles?
# j: -
# j: ¿Llegará
# j: el
# j: momento
# j: -preguntó
# j: el
# j: Hombre-
# j: en
# j: que
# j: los
# j: datos
# j: sean
# j: suficientes
# j: o
# j: el
# j: problema
# j: es
# j: insoluble
# j: en
# j: todas
# j: las
# j: circunstancias
# j: concebibles
# j: ?
# i: La Cósmica AC respondió: NINGÚN PROBLEMA ES INSOLUBLE EN TODAS LAS CIRCUNSTANCIAS CONCEBIBLES.
# j: La
# j: Cósmica
# j: AC
# j: respondió
# j: :
# j: NINGÚN
# j: PROBLEMA
# j: ES
# j: INSOLUBLE
# j: EN
# j: TODAS
# j: LAS
# j: CIRCUNSTANCIAS
# j: CONCEBIBLES
# j: .
# i: El Hombre preguntó: - ¿Cuándo tendrás suficientes datos como para responder a la pregunta?
# j: El
# j: Hombre
# j: preguntó
# j: :
# j: -
# j: ¿Cuándo
# j: tendrás
# j: suficientes
# j: datos
# j: como
# j: para
# j: responder
# j: a
# j: la
# j: pregunta
# j: ?
# i: La Cósmica AC respondió: LOS DATOS SON TODAVÍA INSUFICIENTES PARA UNA RESPUESTA ESCLARECEDORA.
# j: La
# j: Cósmica
# j: AC
# j: respondió
# j: :
# j: LOS
# j: DATOS
# j: SON
# j: TODAVÍA
# j: INSUFICIENTES
# j: PARA
# j: UNA
# j: RESPUESTA
# j: ESCLARECEDORA
# j: .
# i: - ¿Seguirás trabajando en eso?
# j: -
# j: ¿Seguirás
# j: trabajando
# j: en
# j: eso
# j: ?
# i: -preguntó el Hombre.
# j: -preguntó
# j: el
# j: Hombre
# j: .
# i: La Cósmica AC respondió: - SÍ.
# j: La
# j: Cósmica
# j: AC
# j: respondió
# j: :
# j: -
# j: SÍ
# j: .
# i: El Hombre dijo: - Esperaremos.
# j: El
# j: Hombre
# j: dijo
# j: :
# j: -
# j: Esperaremos
# j: .
# i: Las estrellas y las galaxias murieron y se convirtieron en polvo, y el espacio se volvió negro después de tres trillones de años de desgaste.
# j: Las
# j: estrellas
# j: y
# j: las
# j: galaxias
# j: murieron
# j: y
# j: se
# j: convirtieron
# j: en
# j: polvo
# j: ,
# j: y
# j: el
# j: espacio
# j: se
# j: volvió
# j: negro
# j: después
# j: de
# j: tres
# j: trillones
# j: de
# j: años
# j: de
# j: desgaste
# j: .
# i: Uno por uno, el Hombre se fusionó con la AC, cada cuerpo físico perdió su identidad mental en forma tal que no era una pérdida sino una ganancia.
# j: Uno
# j: por
# j: uno
# j: ,
# j: el
# j: Hombre
# j: se
# j: fusionó
# j: con
# j: la
# j: AC
# j: ,
# j: cada
# j: cuerpo
# j: físico
# j: perdió
# j: su
# j: identidad
# j: mental
# j: en
# j: forma
# j: tal
# j: que
# j: no
# j: era
# j: una
# j: pérdida
# j: sino
# j: una
# j: ganancia
# j: .
# i: La última mente del Hombre hizo una pausa antes de la fusión, contemplando un espacio que sólo incluía la borra de la última estrella oscura y nada aparte de esa  15 materia increíblemente delgada, agitada al azar por los restos de un calor que se gastaba, asintóticamente, hasta llegar al cero absoluto.
# j: La
# j: última
# j: mente
# j: del
# j: Hombre
# j: hizo
# j: una
# j: pausa
# j: antes
# j: de
# j: la
# j: fusión
# j: ,
# j: contemplando
# j: un
# j: espacio
# j: que
# j: sólo
# j: incluía
# j: la
# j: borra
# j: de
# j: la
# j: última
# j: estrella
# j: oscura
# j: y
# j: nada
# j: aparte
# j: de
# j: esa
# j: 15
# j: materia
# j: increíblemente
# j: delgada
# j: ,
# j: agitada
# j: al
# j: azar
# j: por
# j: los
# j: restos
# j: de
# j: un
# j: calor
# j: que
# j: se
# j: gastaba
# j: ,
# j: asintóticamente
# j: ,
# j: hasta
# j: llegar
# j: al
# j: cero
# j: absoluto
# j: .
# i: El Hombre dijo: - AC, ¿es éste el final?
# j: El
# j: Hombre
# j: dijo
# j: :
# j: -
# j: AC
# j: ,
# j: ¿es
# j: éste
# j: el
# j: final
# j: ?
# i: ¿Este caos no puede ser revertido al universo una vez más?
# j: ¿Este
# j: caos
# j: no
# j: puede
# j: ser
# j: revertido
# j: al
# j: universo
# j: una
# j: vez
# j: más
# j: ?
# i: ¿Esto no puede hacerse?
# j: ¿Esto
# j: no
# j: puede
# j: hacerse
# j: ?
# i: AC respondió: LOS DATOS SON TODAVÍA INSUFICIENTES PARA UNA RESPUESTA ESCLARECEDORA.
# j: AC
# j: respondió
# j: :
# j: LOS
# j: DATOS
# j: SON
# j: TODAVÍA
# j: INSUFICIENTES
# j: PARA
# j: UNA
# j: RESPUESTA
# j: ESCLARECEDORA
# j: .
# i: La última mente del Hombre se fusionó y sólo AC existió en el hiperespacio.
# j: La
# j: última
# j: mente
# j: del
# j: Hombre
# j: se
# j: fusionó
# j: y
# j: sólo
# j: AC
# j: existió
# j: en
# j: el
# j: hiperespacio
# j: .
# i: La materia y la energía se agotaron y con ellas el espacio y el tiempo.
# j: La
# j: materia
# j: y
# j: la
# j: energía
# j: se
# j: agotaron
# j: y
# j: con
# j: ellas
# j: el
# j: espacio
# j: y
# j: el
# j: tiempo
# j: .
# i: Hasta AC existía solamente para la última pregunta que nunca había sido respondida desde la época en que dos técnicos en computación medio alcoholizados, tres trillones de años antes, formularon la pregunta en la computadora que era para AC mucho menos de lo que para un hombre el Hombre.
# j: Hasta
# j: AC
# j: existía
# j: solamente
# j: para
# j: la
# j: última
# j: pregunta
# j: que
# j: nunca
# j: había
# j: sido
# j: respondida
# j: desde
# j: la
# j: época
# j: en
# j: que
# j: dos
# j: técnicos
# j: en
# j: computación
# j: medio
# j: alcoholizados
# j: ,
# j: tres
# j: trillones
# j: de
# j: años
# j: antes
# j: ,
# j: formularon
# j: la
# j: pregunta
# j: en
# j: la
# j: computadora
# j: que
# j: era
# j: para
# j: AC
# j: mucho
# j: menos
# j: de
# j: lo
# j: que
# j: para
# j: un
# j: hombre
# j: el
# j: Hombre
# j: .
# i: Todas las otras preguntas habían sido contestadas, y hasta que esa última pregunta fuera respondida también, AC no podría liberar su conciencia.
# j: Todas
# j: las
# j: otras
# j: preguntas
# j: habían
# j: sido
# j: contestadas
# j: ,
# j: y
# j: hasta
# j: que
# j: esa
# j: última
# j: pregunta
# j: fuera
# j: respondida
# j: también
# j: ,
# j: AC
# j: no
# j: podría
# j: liberar
# j: su
# j: conciencia
# j: .
# i: Todos los datos recogidos habían llegado al fin.
# j: Todos
# j: los
# j: datos
# j: recogidos
# j: habían
# j: llegado
# j: al
# j: fin
# j: .
# i: No quedaba nada para recoger.
# j: No
# j: quedaba
# j: nada
# j: para
# j: recoger
# j: .
# i: Pero toda la información reunida todavía tenía que ser completamente correlacionada y unida en todas sus posibles relaciones.
# j: Pero
# j: toda
# j: la
# j: información
# j: reunida
# j: todavía
# j: tenía
# j: que
# j: ser
# j: completamente
# j: correlacionada
# j: y
# j: unida
# j: en
# j: todas
# j: sus
# j: posibles
# j: relaciones
# j: .
# i: Se dedicó un intervalo sin tiempo a hacer esto.
# j: Se
# j: dedicó
# j: un
# j: intervalo
# j: sin
# j: tiempo
# j: a
# j: hacer
# j: esto
# j: .
# i: Y sucedió que AC aprendió cómo revertir la dirección de la entropía.
# j: Y
# j: sucedió
# j: que
# j: AC
# j: aprendió
# j: cómo
# j: revertir
# j: la
# j: dirección
# j: de
# j: la
# j: entropía
# j: .
# i: Pero no había ningún Hombre a quien AC pudiera dar una respuesta a la última pregunta.
# j: Pero
# j: no
# j: había
# j: ningún
# j: Hombre
# j: a
# j: quien
# j: AC
# j: pudiera
# j: dar
# j: una
# j: respuesta
# j: a
# j: la
# j: última
# j: pregunta
# j: .
# i: No había materia.
# j: No
# j: había
# j: materia
# j: .
# i: La respuesta -por demostración- se ocuparía de eso también.
# j: La
# j: respuesta
# j: -por
# j: demostración-
# j: se
# j: ocuparía
# j: de
# j: eso
# j: también
# j: .
# i: Durante otro intervalo sin tiempo, AC pensó en la mejor forma de hacerlo.
# j: Durante
# j: otro
# j: intervalo
# j: sin
# j: tiempo
# j: ,
# j: AC
# j: pensó
# j: en
# j: la
# j: mejor
# j: forma
# j: de
# j: hacerlo
# j: .
# i: Cuidadosamente, AC organizó el programa.
# j: Cuidadosamente
# j: ,
# j: AC
# j: organizó
# j: el
# j: programa
# j: .
# i: La conciencia de AC abarcó todo lo que alguna vez había sido un universo y pensó en lo que en ese momento era el caos.
# j: La
# j: conciencia
# j: de
# j: AC
# j: abarcó
# j: todo
# j: lo
# j: que
# j: alguna
# j: vez
# j: había
# j: sido
# j: un
# j: universo
# j: y
# j: pensó
# j: en
# j: lo
# j: que
# j: en
# j: ese
# j: momento
# j: era
# j: el
# j: caos
# j: .
# i: Paso a paso, había que hacerlo.
# j: Paso
# j: a
# j: paso
# j: ,
# j: había
# j: que
# j: hacerlo
# j: .
# i: Y AC dijo:  16 ¡HÁGASE LA LUZ!
# j: Y
# j: AC
# j: dijo
# j: :
# j: 16
# j: ¡HÁGASE
# j: LA
# j: LUZ
# j: !
# i: Y la luz se hizo...
# j: Y
# j: la
# j: luz
# j: se
# j: hizo
# j: ...

# %%
# Create CBOW model 
model1 = gensim.models.Word2Vec(data, min_count=1, 
							size=100, window = 5, sg=False) 

"""
size: The number of dimensions of the embeddings and the default is 100.

window: The maximum distance between a target word and words around the target word. The default window is 5.

min_count: The minimum count of words to consider when training the model; words with occurrence less than this count will be ignored. The default for min_count is 5.

workers: The number of partitions during training and the default workers is 3.

sg: The training algorithm, either CBOW(0) or skip gram(1). The default training algorithm is CBOW.
"""

# Print results 
print("Cosine similarity between 'última' " +
			"and 'pregunta': ", 
	model1.similarity('última', 'pregunta')) 

print("Cosine similarity between 'a' " +
			"and 'con' - Skip Gram : ", 
	model1.similarity('a', 'con')) 

# se fue a parla con su madre, W=2

#parla con Windows=2 tiene: 

# - fue
# - a
# - con
# - su

print("Cosine similarity between 'a' " +
			", '.' - Skip Gram : ", 
	model1.similarity(',', '.'))
# Out:
# Cosine similarity between &#39;última&#39; and &#39;pregunta&#39;:  0.5213699
# Cosine similarity between &#39;a&#39; and &#39;con&#39; - Skip Gram :  0.89105
# Cosine similarity between &#39;a&#39; , &#39;.&#39; - Skip Gram :  0.9449731

# %%
# Create Skip Gram model 
model2 = gensim.models.Word2Vec(data, min_count = 1, size = 100, 
											window = 2, sg = True) 
print()

# Print results 
print("Cosine similarity between 'última' " +
		"and 'pregunta' - Skip Gram : ", 
	model2.similarity('última', 'pregunta')) 
	
print("Cosine similarity between 'a' and 'con' - Skip Gram : ", 
	model2.similarity('a', 'con')) 

print("Cosine similarity between ',' " +
			", '.' - Skip Gram : ", 
	model2.similarity(',', '.')) 

print("Cosine similarity between 'el' " +
			", 'sabes' - Skip Gram : ", 
	model2.similarity('el', 'sabes'))
# Out:
# Cosine similarity between &#39;última&#39; and &#39;pregunta&#39; - Skip Gram :  0.9099757
# Cosine similarity between &#39;a&#39; and &#39;con&#39; - Skip Gram :  0.9737282
# Cosine similarity between &#39;,&#39; , &#39;.&#39; - Skip Gram :  0.9907115
# Cosine similarity between &#39;el&#39; , &#39;sabes&#39; - Skip Gram :  0.44975764

# %%
model1["a"].shape
# Out:
# (100,)

# %%
a_cbow = model1["a"]
a_cbow
# Out:
# array([-0.01156786,  0.01855263,  0.01079609, -0.00626368,  0.00809531,
#        -0.00624729, -0.01544825, -0.00248239,  0.00195   ,  0.00923617,
#        -0.00166899,  0.01860289,  0.00532687, -0.0084466 , -0.00137933,
#         0.01082423,  0.00903598,  0.00891561,  0.01086628, -0.00656921,
#        -0.0137769 , -0.01520679,  0.00290717, -0.00600968,  0.0012506 ,
#        -0.00366031,  0.01294392, -0.00999612, -0.0189226 ,  0.01217176,
#        -0.00472455, -0.00245149, -0.01079574, -0.01243077, -0.01716385,
#         0.01975906, -0.0013603 , -0.00239315,  0.02548251,  0.00289983,
#        -0.00801181,  0.00390241,  0.00646544,  0.01943842,  0.00295296,
#         0.00212451, -0.00142943, -0.01342232, -0.0036922 ,  0.00622298,
#        -0.01210488,  0.01605439, -0.02163083, -0.01189295,  0.01318746,
#         0.00498589, -0.00087954,  0.01981544, -0.01424491,  0.00981503,
#         0.00231991, -0.00039012, -0.01515253, -0.02231973, -0.00832111,
#         0.00493417,  0.00400392,  0.01003456, -0.00719395,  0.01539538,
#         0.02164556,  0.00345465,  0.01161055,  0.00743892,  0.00532672,
#         0.00942774,  0.00047569, -0.00932011, -0.00074141, -0.01226447,
#        -0.00838085,  0.01086828, -0.0050081 ,  0.0039754 , -0.00047404,
#        -0.00505963, -0.01127552,  0.01042584,  0.00608198, -0.01482056,
#        -0.002844  ,  0.00211325, -0.00199505,  0.00028969,  0.01942343,
#         0.00050379, -0.00970436,  0.00377457,  0.00416469,  0.00623189],
#       dtype=float32)

# %%
a_skip_gram = model1["con"]
a_skip_gram
# Out:
# array([-0.01079259,  0.01029936,  0.00571149, -0.00509192,  0.00393262,
#        -0.00096944, -0.00828474, -0.00378647,  0.0023945 ,  0.00325093,
#        -0.00851331,  0.00725531,  0.00814505, -0.01306664,  0.00276756,
#         0.01219913, -0.00108359,  0.00202658,  0.01172477, -0.01232362,
#        -0.01580103, -0.01750437,  0.00261864,  0.0023089 ,  0.00497387,
#        -0.00061446,  0.01161233, -0.00649587, -0.01079162,  0.00721913,
#        -0.00722777,  0.00183884, -0.01348574, -0.00746397, -0.01930797,
#         0.01590571, -0.00322532, -0.00898069,  0.01156808,  0.0014992 ,
#        -0.00399988,  0.00274295,  0.00148905,  0.01411995,  0.00383424,
#         0.00479612, -0.00143048, -0.00779283, -0.00350641,  0.00830307,
#        -0.00585208,  0.01832539, -0.01871698, -0.01087002,  0.0098867 ,
#         0.00660261, -0.00026011,  0.01507577, -0.00629635,  0.00902724,
#         0.0053551 , -0.00610751, -0.01241292, -0.01242599, -0.00967421,
#         0.00742552, -0.00045224,  0.00464402, -0.00645739,  0.01235823,
#         0.01495933,  0.00711676,  0.01099484,  0.01032817,  0.0011659 ,
#         0.00745101,  0.00026369, -0.01161718,  0.00160319, -0.00503903,
#         0.00128517,  0.00784519, -0.00173754,  0.00300779,  0.00762295,
#        -0.00295857, -0.00293795,  0.00352387, -0.00038026, -0.01780767,
#         0.00126258, -0.00362398,  0.00636442, -0.0025832 ,  0.01571841,
#         0.00037697, -0.00261735,  0.00326228,  0.00170408,  0.0039573 ],
#       dtype=float32)

# %%
input = "a"
y = "preposicion"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# &lt;ipython-input-9-c6f62b58c8c9&gt; in &lt;module&gt;
# ----&gt; 1 input = a
#       2 y = &quot;preposicion&quot;
#
# NameError: name &#39;a&#39; is not defined

# %%
tweet = Eso es lo mejor!

tweet_y = "Positivo"
