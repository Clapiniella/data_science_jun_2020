# %% [markdown]
# ### ReLu

# %%
def ReLU(x):
    return (abs(x) + x) / 2

# %%
ReLU(55)
# Out:
# 55.0

# %% [markdown]
# ### Sigmoid

# %%
import math

def sigmoid(x):
  return 1 / (1 + math.exp(-x))

# %% [markdown]
# ## TESTING

# %%
import numpy as np
import matplotlib.pylab as plt

_ = np.arange(10)
x_ = np.random.random(10) - 5
x_
# Out:
# array([-4.31703541, -4.48388536, -4.15324213, -4.16367541, -4.56751939,
#        -4.0356961 , -4.54453867, -4.07841445, -4.56172252, -4.55980592])

# %%
plt.plot(_, x_)

# %%
plt.plot(_, ReLU(x_))

# %%
y_sigmoid_ = [sigmoid(x) for x in y_]

plt.plot(x_, y_sigmoid_)
